# %% [markdown]
# - NoSql 非关系性数据库
#
# [Linux下mongodb的安装与环境配置](https://www.cnblogs.com/xiaofeideboke/p/9837648.html)
#
# [在Ubuntu下进行MongoDB安装步骤](https://www.cnblogs.com/shileima/p/7823434.html)
#
# [python操作MongoDB](https://www.cnblogs.com/melonjiang/p/6536876.html)
#
# - 安装
# ```shell
# sudo apt-get install mongodb
# sudo apt-get install mongodb-org
# ```
#
# - 启动服务
#
# ```shell
# sudo service mongod start
# sudo service mongod stop
# sudo service mongod restart
# sudo service mongodb restart
# sudo service mongodb start
# sudo service mongodb stop
# ```
#
# - 普通的启动方法
#
# ```shell
# sudo mongod --config /user/local/mongodb/mongod.conf
#
# ```
#
# - 启动客户端
#
# ```shell
# mongo
# ```
# - 端口27017
#
# - 查看是否启动
# ```shell
# ps -ef | grep mongod
# ```

# %% [markdown]
# # mongodb的增删改查
#
# [MongoDB增删改查操作](https://www.cnblogs.com/zhuminghui/p/8330429.html)

# %% [markdown]
# # ================================
# ![image.png](attachment:image.png)

# %% [markdown]
# ****
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # =======================================
#
# ![image.png](attachment:image.png)
