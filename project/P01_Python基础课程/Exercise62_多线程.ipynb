# %% [markdown]
# ## 多线程VS多进程
# * 程序的一个运行叫一个进程
# * 一个进程里面有多个线程
# * 共享互斥问题
# * 一个进程多个线程间共享数据和上下文运行环境
# * 进程：程序的一次执行（程序装载入内存，系统分配资
#     源运行）。
# * 每个进程有自己的内存空间、数据栈等，只能使用进
#   程间通讯，而不能直接共享信息。
# * 线程：所有线程运行在同一个进程中，共享相同的运行
#   环境。
# * 每个独立的线程有一个程序运行的入口、顺序执行
#   序列和程序的出口。
# * 线程的运行可以被抢占（中断），或暂时被挂起
#   （睡眠），让其他线程运行（让步）。
# *  一个进程中的各个线程间共享同一片数据空间。

# %%
import time
import _thread as thread

def loop1():
    print("start loop at :", time.ctime())
    time.sleep(4)
    print("end loop at: ", time.ctime())
    
def loop2():
    # ctime 获取当前时间
    print("start loop at :", time.ctime())
    # 睡眠多长时间，单位秒
    time.sleep(2)
    print("end loop at: ", time.ctime())
    
def main():
    print("start at:", time.ctime)
    #启动多线程的意思是用多线程去执行某个函数
    # 启动多线程函数为start_new_thread
    #参数两个，一个是需要运行的函数，第二个是函数的参数作为元组使用
    # 为空则使用空元祖
    # 注意如果函数只有一个参数，需要参数后有一个逗号
    thread.start_new_thread(loop1,())
    thread.start_new_thread(loop2,())
    print("All done at :", time.ctime())
    
if __name__ == "__main__":
    main()
    while True:
        time.sleep(1)

# %%
import time
import _thread as thread

def loop1(in1):
    print("start loop at :", time.ctime())
    print("我是参数",in1)
    time.sleep(4)
    print("end loop at: ", time.ctime())
    
def loop2(in1,in2):
    # ctime 获取当前时间
    print("start loop at :", time.ctime())
    # 睡眠多长时间，单位秒
    print("我是参数 ",in1,"和参数 ",in2)
    time.sleep(2)
    print("end loop at: ", time.ctime())
    
def main():
    print("start at:", time.ctime)
    #启动多线程的意思是用多线程去执行某个函数
    # 启动多线程函数为start_new_thread
    #参数两个，一个是需要运行的函数，第二个是函数的参数作为元组使用
    # 为空则使用空元祖
    # 注意如果函数只有一个参数，需要参数后有一个逗号
    thread.start_new_thread(loop1,("王老大",))
    thread.start_new_thread(loop2,("王大鹏","王晓鹏",))
    print("All done at :", time.ctime())
    
if __name__ == "__main__":
    main()
    while True:
        time.sleep(10)
# Out:
# start at: <built-in function ctime>
# All done at :start loop at :start loop at : Thu Jul 19 21:37:53 2018 Thu Jul 19 21:37:53 2018
# 我是参数  王大鹏 和参数
# 我是参数 王老大
#  王晓鹏
#  Thu Jul 19 21:37:53 2018
# end loop at:  Thu Jul 19 21:37:55 2018
# end loop at:  Thu Jul 19 21:37:57 2018

# %% [markdown]
# ##  threading 的使用
#  *  t = threading.Thread(target=xxx, arg=(xxx,))
#  *  t.start() 启动多线程
#  *  t.join()  等待多线程执行完

# %%
# 比较实用的代码 作业
# 企业里面常用

import threading
from time import sleep, ctime


loop = [4,2]

class ThreadFunc:

    def __init__(self, name):
        self.name = name

    def loop(self, nloop, nsec):
        '''
        :param nloop: loop函数的名称
        :param nsec: 系统休眠时间
        :return:
        '''
        print('Start loop ', nloop, 'at ', ctime())
        sleep(nsec)
        print('Done loop ', nloop, ' at ', ctime())

def main():
    print("Starting at: ", ctime())

    # ThreadFunc("loop").loop 跟一下两个式子相等：
    # t = ThreadFunc("loop")
    # t.loop
    # 以下t1 和  t2的定义方式相等
    t = ThreadFunc("loop")
    t1 = threading.Thread( target = t.loop, args=("LOOP1", 4))
    # 下面这种写法更西方人，工业化一点
    t2 = threading.Thread( target = ThreadFunc('loop').loop, args=("LOOP2", 2))

    # 常见错误写法
    #t1 = threading.Thread(target=ThreadFunc('loop').loop(100,4))
    #t2 = threading.Thread(target=ThreadFunc('loop').loop(100,2))

    t1.start()
    t2.start()

    t1.join( )
    t2.join()


    print("ALL done at: ", ctime())


if __name__ == '__main__':
    main()

# %%
import threading

sum = 0
loopSum = 1000000


lock = threading.Lock()


def myAdd():
    global  sum, loopSum

    for i in range(1, loopSum):
        # 上锁，申请锁
        lock.acquire()
        sum += 1
        # 释放锁
        lock.release()


def myMinu():
    global  sum, loopSum
    for i in range(1, loopSum):
        lock.acquire()
        sum -= 1
        lock.release()

if __name__ == '__main__':
    print("Starting ....{0}".format(sum))

    # 开始多线程的实例，看执行结果是否一样
    t1 = threading.Thread(target=myAdd, args=())
    t2 = threading.Thread(target=myMinu, args=())

    t1.start()
    t2.start()

    t1.join()
    t2.join()

    print("Done .... {0}".format(sum))
# Out:
# Starting ....0
# Done .... 0

# %%
#encoding=utf-8
import threading
import time

# Python2
# from Queue import Queue

# Python3
import queue


class Producer(threading.Thread):
    def run(self):
        global queue
        count = 0
        while True:
            # qsize返回queue内容长度
            if queue.qsize() < 1000:
                for i in range(100):
                    count = count +1
                    msg = '生成产品'+str(count)
                    # put是网queue中放入一个值
                    queue.put(msg)
                    print(msg)
            time.sleep(0.5)


class Consumer(threading.Thread):
    def run(self):
        global queue
        while True:
            if queue.qsize() > 100:
                for i in range(3):
                    # get是从queue中取出一个值
                    msg = self.name + '消费了 '+queue.get()
                    print(msg)
            time.sleep(1)


if __name__ == '__main__':
    queue = queue.Queue()

    for i in range(500):
        queue.put('初始产品'+str(i))
    for i in range(2):
        p = Producer()
        p.start()
    for i in range(5):
        c = Consumer()
        c.start()
# Out:
# 生成产品1
# 生成产品2
# 生成产品3
# 生成产品4
# 生成产品5
# 生成产品6
# 生成产品7
# 生成产品8
# 生成产品9
# 生成产品10
# 生成产品11
# 生成产品12
# 生成产品13
# 生成产品14
# 生成产品15
# 生成产品16
# 生成产品17
# 生成产品18
# 生成产品19
# 生成产品20
# 生成产品21
# 生成产品22
# 生成产品23
# 生成产品24
# 生成产品25
# 生成产品26
# 生成产品27
# 生成产品28生成产品1
# 生成产品29
# 生成产品30
# 生成产品31
# 生成产品32
# 生成产品33
# 生成产品34
# 生成产品35
# 生成产品36
# 生成产品37
# 生成产品38
# 生成产品39
# 生成产品40
# 生成产品41
# 生成产品42
# 生成产品43
# 生成产品44
# 生成产品45
# 生成产品46
# 生成产品47
# 生成产品48
# 生成产品49
# 生成产品50
# 生成产品51
# 生成产品52
# 生成产品53
# 生成产品54
# 生成产品55
# 生成产品56
# 生成产品57
# 生成产品58
# 生成产品59
# 生成产品60
# 生成产品61
# 生成产品62
# Thread-10消费了 初始产品0
# 生成产品63
# 生成产品64
# 生成产品65
# 生成产品66
# 生成产品67
# 生成产品68
# 生成产品69
# 生成产品70
# 生成产品71
# 生成产品72
# 生成产品73
# 生成产品74
# 生成产品75
# 生成产品76
# 生成产品77
# 生成产品78
# 生成产品2生成产品79Thread-11消费了 初始产品1
#
#
# Thread-11消费了 初始产品2
# Thread-11消费了 初始产品3
# 生成产品80Thread-12消费了 初始产品4
#
# 生成产品3Thread-10消费了 初始产品5
# Thread-10消费了 初始产品6
#
# 生成产品4
# 生成产品5
# 生成产品6
# 生成产品7
# 生成产品8
# 生成产品9
# 生成产品10
# 生成产品11
# 生成产品12
# 生成产品13
# 生成产品14
# 生成产品15
# 生成产品16
# 生成产品17
# 生成产品18
# 生成产品19
# 生成产品20
# 生成产品21
# 生成产品22
# 生成产品23
# 生成产品24
# 生成产品25
# Thread-12消费了 初始产品7生成产品81
# Thread-12消费了 初始产品8
#
# 生成产品26
#
# 生成产品82
# 生成产品83
# 生成产品84
# 生成产品85
# 生成产品86
# 生成产品87
# 生成产品88
# 生成产品89
# 生成产品90
# 生成产品91
# 生成产品92生成产品27
# 生成产品28
# 生成产品29
# 生成产品30
# 生成产品31
# 生成产品32
# 生成产品33
# 生成产品34
# 生成产品35
# 生成产品36
# 生成产品37
# 生成产品38
# 生成产品39
# 生成产品40
# 生成产品41
# 生成产品42
# 生成产品93
# 生成产品94
# 生成产品95
# 生成产品96
# 生成产品97
# 生成产品98
# 生成产品99
# 生成产品100
#
# 生成产品43
# 生成产品44
# 生成产品45
# 生成产品46
# 生成产品47
# 生成产品48
# 生成产品49
# 生成产品50
# 生成产品51
# 生成产品52
# 生成产品53
# 生成产品54
# 生成产品55
# 生成产品56
# 生成产品57
# 生成产品58
# 生成产品59
# 生成产品60
# 生成产品61
# Thread-13消费了 初始产品9生成产品62
#
# Thread-13消费了 初始产品10
# Thread-13消费了 初始产品11
# Thread-14消费了 初始产品12生成产品63
#
# Thread-14消费了 初始产品13
# Thread-14消费了 初始产品14
# 生成产品64
# 生成产品65
# 生成产品66
# 生成产品67
# 生成产品68
# 生成产品69
# 生成产品70
# 生成产品71
# 生成产品72
# 生成产品73
# 生成产品74
# 生成产品75
# 生成产品76
# 生成产品77
# 生成产品78
# 生成产品79
# 生成产品80
# 生成产品81
# 生成产品82
# 生成产品83
# 生成产品84
# 生成产品85
# 生成产品86
# 生成产品87
# 生成产品88
# 生成产品89
# 生成产品90
# 生成产品91
# 生成产品92
# 生成产品93
# 生成产品94
# 生成产品95
# 生成产品96
# 生成产品97
# 生成产品98
# 生成产品99
# 生成产品100
# 生成产品101
# 生成产品102
# 生成产品103
# 生成产品104
# 生成产品105
# 生成产品106
# 生成产品107
# 生成产品108
# 生成产品109
# 生成产品110
# 生成产品111
# 生成产品112
# 生成产品113
# 生成产品114
# 生成产品115
# 生成产品116
# 生成产品117
# 生成产品118
# 生成产品119
# 生成产品120
# 生成产品121
# 生成产品122
# 生成产品123
# 生成产品124
# 生成产品125
# 生成产品126
# 生成产品127
# 生成产品128
# 生成产品129
# 生成产品130
# 生成产品131
# 生成产品132
# 生成产品133
# 生成产品134
# 生成产品135
# 生成产品136
# 生成产品137
# 生成产品138
# 生成产品139
# 生成产品140
# 生成产品141
# 生成产品142
# 生成产品143
# 生成产品144
# 生成产品145
# 生成产品146
# 生成产品147
# 生成产品148
# 生成产品149
# 生成产品150
# 生成产品151
# 生成产品152
# 生成产品153
# 生成产品154
# 生成产品155
# 生成产品156
# 生成产品157
# 生成产品158
# 生成产品159
# 生成产品160
# 生成产品161
# 生成产品162
# 生成产品163
# 生成产品164
# 生成产品165
# 生成产品166
# 生成产品167
# 生成产品168
# 生成产品169
# 生成产品170
# 生成产品171
# 生成产品172
# 生成产品173
# 生成产品174
# 生成产品175
# 生成产品176
# 生成产品177
# 生成产品178
# 生成产品179
# 生成产品180
# 生成产品181
# 生成产品182
# 生成产品183
# 生成产品184
# 生成产品185
# 生成产品186
# 生成产品187
# 生成产品188
# 生成产品189
# 生成产品190
# 生成产品191
# 生成产品192
# 生成产品193
# 生成产品194
# 生成产品195
# 生成产品196
# 生成产品197
# 生成产品198
# 生成产品199
# 生成产品200
# 生成产品101
# 生成产品102
# 生成产品103
# 生成产品104
# 生成产品105
# 生成产品106
# 生成产品107
# 生成产品108
# 生成产品109
# 生成产品110
# 生成产品111
# 生成产品112
# 生成产品113
# 生成产品114
# 生成产品115
# 生成产品116
# 生成产品117
# 生成产品118
# 生成产品119
# 生成产品120
# 生成产品121
# 生成产品122
# 生成产品123
# 生成产品124
# 生成产品125
# 生成产品126
# 生成产品127
# 生成产品128
# 生成产品129
# 生成产品130
# 生成产品131
# 生成产品132
# 生成产品133
# 生成产品134
# 生成产品135
# 生成产品136
# 生成产品137
# 生成产品138
# 生成产品139
# 生成产品140
# 生成产品141
# 生成产品142
# 生成产品143
# 生成产品144
# 生成产品145
# 生成产品146
# 生成产品147
# 生成产品148
# 生成产品149
# 生成产品150
# 生成产品151
# 生成产品152
# 生成产品153
# 生成产品154
# 生成产品155
# 生成产品156
# 生成产品157
# 生成产品158
# 生成产品159
# 生成产品160
# 生成产品161
# 生成产品162
# 生成产品163
# 生成产品164
# 生成产品165
# 生成产品166
# 生成产品167
# 生成产品168
# 生成产品169
# 生成产品170
# 生成产品171
# 生成产品172
# 生成产品173
# 生成产品174
# 生成产品175
# 生成产品176
# 生成产品177
# 生成产品178
# 生成产品179
# 生成产品180
# 生成产品181
# 生成产品182
# 生成产品183
# 生成产品184
# 生成产品185
# 生成产品186
# 生成产品187
# 生成产品188
# 生成产品189
# 生成产品190
# 生成产品191
# 生成产品192
# 生成产品193
# 生成产品194
# 生成产品195
# 生成产品196
# 生成产品197
# 生成产品198
# 生成产品199
# 生成产品200
# Thread-11消费了 初始产品15
# Thread-11消费了 初始产品16
# Thread-11消费了 初始产品17
# Thread-10消费了 初始产品18
# Thread-12消费了 初始产品19
# Thread-12消费了 初始产品20
# Thread-12消费了 初始产品21
# Thread-10消费了 初始产品22
# Thread-10消费了 初始产品23
# 生成产品201
# 生成产品202
# 生成产品203
# Thread-13消费了 初始产品24
# 生成产品204
# 生成产品205
# 生成产品206
# Thread-13消费了 初始产品25
# Thread-13消费了 初始产品26
# 生成产品207
# 生成产品208
# 生成产品209
# 生成产品210
# 生成产品211
# 生成产品212
# 生成产品213
# 生成产品214
# 生成产品215
# 生成产品216
# 生成产品217
# 生成产品218
# 生成产品219
# 生成产品220
# 生成产品221
# 生成产品222
# 生成产品223
# 生成产品224
# 生成产品225
# 生成产品226
# 生成产品227
# 生成产品228
# 生成产品229
# 生成产品230
# 生成产品231
# 生成产品232
# 生成产品233
# 生成产品234
# 生成产品235
# 生成产品236
# 生成产品237
# 生成产品238
# 生成产品239
# 生成产品240
# 生成产品241
# 生成产品242
# 生成产品243
# 生成产品244
# 生成产品245
# 生成产品246
# 生成产品247
# 生成产品248
# 生成产品249
# 生成产品250
# 生成产品251
# 生成产品252
# 生成产品253
# 生成产品254
# 生成产品255
# 生成产品256
# 生成产品257
# 生成产品258
# 生成产品259
# 生成产品260
# 生成产品261
# 生成产品262
# 生成产品263
# 生成产品264
# 生成产品265
# 生成产品266
# 生成产品267
# 生成产品268
# 生成产品269
# 生成产品270
# 生成产品271
# 生成产品272
# 生成产品273
# 生成产品274
# 生成产品275
# 生成产品276
# 生成产品277
# 生成产品278
# 生成产品279
# 生成产品280
# 生成产品281
# 生成产品282
# 生成产品283
# 生成产品284
# 生成产品285
# 生成产品286
# 生成产品287
# 生成产品288
# 生成产品289
# 生成产品290
# 生成产品291
# 生成产品292
# 生成产品293
# 生成产品294
# 生成产品295
# 生成产品296
# 生成产品297
# 生成产品298
# 生成产品299
# 生成产品300
# Thread-14消费了 初始产品27
# Thread-14消费了 初始产品28
# Thread-14消费了 初始产品29
# 生成产品201
# 生成产品202
# 生成产品203
# 生成产品204
# 生成产品205
# 生成产品206
# 生成产品207
# 生成产品208
# 生成产品209
# 生成产品210
# 生成产品211
# 生成产品212
# 生成产品213
# 生成产品214
# 生成产品215
# 生成产品216
# 生成产品217
# 生成产品218
# 生成产品219
# 生成产品220
# 生成产品221
# 生成产品222
# 生成产品223
# 生成产品224
# 生成产品225
# 生成产品226
# 生成产品227
# 生成产品228
# 生成产品229
# 生成产品230
# 生成产品231
# 生成产品232
# 生成产品233
# 生成产品234
# 生成产品235
# 生成产品236
# 生成产品237
# 生成产品238
# 生成产品239
# 生成产品240
# 生成产品241
# 生成产品242
# 生成产品243
# 生成产品244
# 生成产品245
# 生成产品246
# 生成产品247
# 生成产品248
# 生成产品249
# 生成产品250
# 生成产品251
# 生成产品252
# 生成产品253
# 生成产品254
# 生成产品255
# 生成产品256
# 生成产品257
# 生成产品258
# 生成产品259
# 生成产品260
# 生成产品261
# 生成产品262
# 生成产品263
# 生成产品264
# 生成产品265
# 生成产品266
# 生成产品267
# 生成产品268
# 生成产品269
# 生成产品270
# 生成产品271
# 生成产品272
# 生成产品273
# 生成产品274
# 生成产品275
# 生成产品276
# 生成产品277
# 生成产品278
# 生成产品279
# 生成产品280
# 生成产品281
# 生成产品282
# 生成产品283
# 生成产品284
# 生成产品285
# 生成产品286
# 生成产品287
# 生成产品288
# 生成产品289
# 生成产品290
# 生成产品291
# 生成产品292
# 生成产品293
# 生成产品294
# 生成产品295
# 生成产品296
# 生成产品297
# 生成产品298
# 生成产品299
# 生成产品300
# Thread-11消费了 初始产品30
# Thread-11消费了 初始产品31
# Thread-11消费了 初始产品32
# Thread-12消费了 初始产品33
# Thread-10消费了 初始产品34
# Thread-10消费了 初始产品35Thread-12消费了 初始产品36
# Thread-10消费了 初始产品37
#
# Thread-12消费了 初始产品38
# Thread-13消费了 初始产品39
# Thread-13消费了 初始产品40
# Thread-13消费了 初始产品41
# Thread-14消费了 初始产品42
# Thread-14消费了 初始产品43
# Thread-14消费了 初始产品44
# Thread-11消费了 初始产品45
# Thread-11消费了 初始产品46
# Thread-11消费了 初始产品47
# Thread-10消费了 初始产品48Thread-12消费了 初始产品49
# Thread-12消费了 初始产品50
# Thread-12消费了 初始产品51
#
# Thread-10消费了 初始产品52
# Thread-10消费了 初始产品53
# Thread-13消费了 初始产品54
# Thread-13消费了 初始产品55
# Thread-13消费了 初始产品56
# Thread-14消费了 初始产品57
# Thread-14消费了 初始产品58
# Thread-14消费了 初始产品59
# Thread-11消费了 初始产品60
# Thread-11消费了 初始产品61
# Thread-11消费了 初始产品62
# Thread-12消费了 初始产品63
# Thread-10消费了 初始产品64
# Thread-10消费了 初始产品65
# Thread-10消费了 初始产品66
# Thread-12消费了 初始产品67
# Thread-12消费了 初始产品68
# Thread-13消费了 初始产品69
# Thread-13消费了 初始产品70
# Thread-13消费了 初始产品71
# Thread-14消费了 初始产品72
# Thread-14消费了 初始产品73
# Thread-14消费了 初始产品74
# Thread-11消费了 初始产品75
# Thread-11消费了 初始产品76
# Thread-11消费了 初始产品77
# Thread-10消费了 初始产品78Thread-12消费了 初始产品79
# Thread-10消费了 初始产品80
# Thread-10消费了 初始产品81
#
# Thread-12消费了 初始产品82
# Thread-12消费了 初始产品83
# Thread-13消费了 初始产品84
# Thread-13消费了 初始产品85
# Thread-13消费了 初始产品86
# Thread-14消费了 初始产品87
# Thread-14消费了 初始产品88
# Thread-14消费了 初始产品89
# Thread-11消费了 初始产品90
# Thread-11消费了 初始产品91
# Thread-11消费了 初始产品92
# Thread-12消费了 初始产品93
# Thread-12消费了 初始产品94
# Thread-12消费了 初始产品95
# Thread-10消费了 初始产品96
# Thread-10消费了 初始产品97
# Thread-10消费了 初始产品98
# Thread-13消费了 初始产品99
# Thread-13消费了 初始产品100
# Thread-13消费了 初始产品101
# 生成产品301
# 生成产品302
# 生成产品303
# 生成产品304
# 生成产品305
# 生成产品306
# 生成产品307
# 生成产品308
# 生成产品309
# 生成产品310
# 生成产品311
# 生成产品312
# 生成产品313
# 生成产品314
# 生成产品315
# 生成产品316
# 生成产品317
# 生成产品318
# 生成产品319
# 生成产品320
# 生成产品321
# 生成产品322
# 生成产品323
# 生成产品324
# Thread-14消费了 初始产品102生成产品325
# 生成产品326
# 生成产品327
# 生成产品328
# 生成产品329
# 生成产品330
# 生成产品331
# 生成产品332
# 生成产品333
# 生成产品334
# 生成产品335
# 生成产品336
# 生成产品337
# 生成产品338
# 生成产品339
# 生成产品340
#
# 生成产品341
# 生成产品342
# 生成产品343
# 生成产品344
# 生成产品345
# 生成产品346
# 生成产品347
# 生成产品348
# 生成产品349
# 生成产品350
# 生成产品351
# 生成产品352
# 生成产品353
# 生成产品354Thread-14消费了 初始产品103
#
# 生成产品355
# 生成产品356
# 生成产品357
# 生成产品358
# 生成产品359
# 生成产品360
# 生成产品361
# 生成产品362
# Thread-14消费了 初始产品104生成产品363
#
# 生成产品364
# 生成产品365
# 生成产品366
# 生成产品367
# 生成产品368
# 生成产品369
# 生成产品370
# 生成产品371
# 生成产品372
# 生成产品373
# 生成产品374
# 生成产品375
# 生成产品376
# 生成产品377
# 生成产品378
# 生成产品379
# 生成产品380
# 生成产品381
# 生成产品382
# 生成产品383
# 生成产品384
# 生成产品385
# 生成产品386
# 生成产品387
# 生成产品388
# 生成产品389
# 生成产品390
# 生成产品391
# 生成产品392
# 生成产品393
# 生成产品394
# 生成产品395
# 生成产品396
# 生成产品397
# 生成产品398
# 生成产品399
# 生成产品400
# Thread-11消费了 初始产品105
# Thread-11消费了 初始产品106
# Thread-11消费了 初始产品107
# Thread-12消费了 初始产品108
# Thread-12消费了 初始产品109
# Thread-12消费了 初始产品110
# Thread-10消费了 初始产品111
# Thread-10消费了 初始产品112
# Thread-10消费了 初始产品113
# Thread-13消费了 初始产品114
# Thread-13消费了 初始产品115
# Thread-13消费了 初始产品116
# Thread-14消费了 初始产品117
# Thread-14消费了 初始产品118
# Thread-14消费了 初始产品119
# Thread-11消费了 初始产品120
# Thread-11消费了 初始产品121
# Thread-11消费了 初始产品122
# Thread-12消费了 初始产品123
# Thread-12消费了 初始产品124
# Thread-12消费了 初始产品125
# Thread-10消费了 初始产品126
# Thread-10消费了 初始产品127
# Thread-10消费了 初始产品128
# Thread-13消费了 初始产品129
# Thread-13消费了 初始产品130
# Thread-13消费了 初始产品131
# Thread-14消费了 初始产品132
# Thread-14消费了 初始产品133
# Thread-14消费了 初始产品134
# Thread-11消费了 初始产品135
# Thread-11消费了 初始产品136
# Thread-11消费了 初始产品137
# Thread-12消费了 初始产品138
# Thread-12消费了 初始产品139
# Thread-12消费了 初始产品140
# Thread-10消费了 初始产品141
# Thread-10消费了 初始产品142
# Thread-10消费了 初始产品143
# Thread-13消费了 初始产品144
# Thread-13消费了 初始产品145
# Thread-13消费了 初始产品146
# Thread-14消费了 初始产品147
# Thread-14消费了 初始产品148
# Thread-14消费了 初始产品149
# Thread-11消费了 初始产品150
# Thread-11消费了 初始产品151
# Thread-11消费了 初始产品152
# Thread-12消费了 初始产品153
# Thread-12消费了 初始产品154
# Thread-10消费了 初始产品155Thread-12消费了 初始产品156
#
# Thread-10消费了 初始产品157
# Thread-10消费了 初始产品158
# Thread-13消费了 初始产品159
# Thread-13消费了 初始产品160
# Thread-13消费了 初始产品161
# Thread-14消费了 初始产品162
# Thread-14消费了 初始产品163
# Thread-14消费了 初始产品164
# Thread-11消费了 初始产品165
# Thread-11消费了 初始产品166
# Thread-11消费了 初始产品167
# Thread-12消费了 初始产品168
# Thread-12消费了 初始产品169
# Thread-12消费了 初始产品170
# Thread-10消费了 初始产品171
# Thread-10消费了 初始产品172
# Thread-10消费了 初始产品173
# Thread-13消费了 初始产品174
# Thread-13消费了 初始产品175
# Thread-13消费了 初始产品176
# Thread-14消费了 初始产品177
# Thread-14消费了 初始产品178
# Thread-14消费了 初始产品179
# Thread-11消费了 初始产品180
# Thread-11消费了 初始产品181
# Thread-11消费了 初始产品182
# Thread-10消费了 初始产品183Thread-12消费了 初始产品184
#
# Thread-10消费了 初始产品185
# Thread-10消费了 初始产品186
# Thread-12消费了 初始产品187
# Thread-12消费了 初始产品188
# Thread-13消费了 初始产品189
# Thread-13消费了 初始产品190
# Thread-13消费了 初始产品191
# Thread-14消费了 初始产品192
# Thread-14消费了 初始产品193
# Thread-14消费了 初始产品194
# Thread-11消费了 初始产品195
# Thread-11消费了 初始产品196
# Thread-11消费了 初始产品197
# Thread-10消费了 初始产品198
# Thread-12消费了 初始产品199Thread-10消费了 初始产品200
# Thread-12消费了 初始产品201
# Thread-12消费了 初始产品202
#
# Thread-10消费了 初始产品203
# Thread-13消费了 初始产品204
# Thread-13消费了 初始产品205
# Thread-13消费了 初始产品206
# 生成产品301
# 生成产品302
# 生成产品303
# 生成产品304
# 生成产品305
# Thread-14消费了 初始产品207生成产品306
# Thread-14消费了 初始产品208
# Thread-14消费了 初始产品209
#
# 生成产品307
# 生成产品308
# 生成产品309
# 生成产品310
# 生成产品311
# 生成产品312
# 生成产品313
# 生成产品314
# 生成产品315
# 生成产品316
# 生成产品317
# 生成产品318
# 生成产品319
# 生成产品320
# 生成产品321
# 生成产品322
# 生成产品323
# 生成产品324
# 生成产品325
# 生成产品326
# 生成产品327
# 生成产品328
# 生成产品329
# 生成产品330
# 生成产品331
# 生成产品332
# 生成产品333
# 生成产品334
# 生成产品335
# 生成产品336
# 生成产品337
# 生成产品338
# 生成产品339
# 生成产品340
# 生成产品341
# 生成产品342
# 生成产品343
# 生成产品344
# 生成产品345
# 生成产品346
# 生成产品347
# 生成产品348
# 生成产品349
# 生成产品350
# 生成产品351
# 生成产品352
# 生成产品353
# 生成产品354
# 生成产品355
# 生成产品356
# 生成产品357
# 生成产品358
# 生成产品359
# 生成产品360
# 生成产品361
# 生成产品362
# 生成产品363
# 生成产品364
# 生成产品365
# 生成产品366
# 生成产品367
# 生成产品368
# 生成产品369
# 生成产品370
# 生成产品371
# 生成产品372
# 生成产品373
# 生成产品374
# 生成产品375
# 生成产品376
# 生成产品377
# 生成产品378
# 生成产品379
# 生成产品380
# 生成产品381
# 生成产品382
# 生成产品383
# 生成产品384
# 生成产品385
# 生成产品386
# 生成产品387
# 生成产品388
# 生成产品389
# 生成产品390
# 生成产品391
# 生成产品392
# 生成产品393
# 生成产品394
# 生成产品395
# 生成产品396
# 生成产品397
# 生成产品398
# 生成产品399
# 生成产品400
# Thread-11消费了 初始产品210
# Thread-11消费了 初始产品211
# Thread-11消费了 初始产品212
# Thread-12消费了 初始产品213
# Thread-10消费了 初始产品214
# Thread-12消费了 初始产品215Thread-10消费了 初始产品216
# Thread-10消费了 初始产品217
#
# Thread-12消费了 初始产品218
# Thread-13消费了 初始产品219
# Thread-13消费了 初始产品220
# Thread-13消费了 初始产品221
# Thread-14消费了 初始产品222
# Thread-14消费了 初始产品223
# Thread-14消费了 初始产品224
# Thread-11消费了 初始产品225
# Thread-11消费了 初始产品226
# Thread-11消费了 初始产品227
# Thread-12消费了 初始产品228Thread-10消费了 初始产品229
# Thread-10消费了 初始产品230
# Thread-12消费了 初始产品231
# Thread-12消费了 初始产品232
#
# Thread-10消费了 初始产品233
# Thread-13消费了 初始产品234
# Thread-13消费了 初始产品235
# Thread-13消费了 初始产品236
# Thread-14消费了 初始产品237
# Thread-14消费了 初始产品238
# Thread-14消费了 初始产品239
# Thread-11消费了 初始产品240
# Thread-11消费了 初始产品241
# Thread-11消费了 初始产品242
# Thread-12消费了 初始产品243
# Thread-12消费了 初始产品244
# Thread-12消费了 初始产品245
# Thread-10消费了 初始产品246
# Thread-10消费了 初始产品247
# Thread-10消费了 初始产品248
# Thread-13消费了 初始产品249
# Thread-13消费了 初始产品250
# Thread-13消费了 初始产品251
# Thread-14消费了 初始产品252
# Thread-14消费了 初始产品253
# Thread-14消费了 初始产品254
# Thread-11消费了 初始产品255
# Thread-11消费了 初始产品256
# Thread-11消费了 初始产品257
# Thread-12消费了 初始产品258
# Thread-12消费了 初始产品259
# Thread-12消费了 初始产品260
# Thread-10消费了 初始产品261
# Thread-10消费了 初始产品262
# Thread-10消费了 初始产品263
# Thread-13消费了 初始产品264
# Thread-13消费了 初始产品265
# Thread-13消费了 初始产品266
# Thread-14消费了 初始产品267
# Thread-14消费了 初始产品268
# Thread-14消费了 初始产品269
# Thread-11消费了 初始产品270
# Thread-11消费了 初始产品271
# Thread-11消费了 初始产品272
# Thread-12消费了 初始产品273
# Thread-12消费了 初始产品274
# Thread-12消费了 初始产品275
# Thread-10消费了 初始产品276
# Thread-10消费了 初始产品277
# Thread-10消费了 初始产品278
# Thread-13消费了 初始产品279
# Thread-13消费了 初始产品280
# Thread-13消费了 初始产品281
# Thread-14消费了 初始产品282
# Thread-14消费了 初始产品283
# Thread-14消费了 初始产品284
# Thread-11消费了 初始产品285
# Thread-11消费了 初始产品286
# Thread-11消费了 初始产品287
# Thread-12消费了 初始产品288
# Thread-12消费了 初始产品289
# Thread-12消费了 初始产品290
# Thread-10消费了 初始产品291
# Thread-10消费了 初始产品292
# Thread-10消费了 初始产品293
# Thread-13消费了 初始产品294
# Thread-13消费了 初始产品295
# Thread-13消费了 初始产品296
# Thread-14消费了 初始产品297
# Thread-14消费了 初始产品298
# Thread-14消费了 初始产品299
# Thread-11消费了 初始产品300
# Thread-11消费了 初始产品301
# Thread-11消费了 初始产品302
# Thread-12消费了 初始产品303
# Thread-12消费了 初始产品304
# Thread-12消费了 初始产品305
# Thread-10消费了 初始产品306
# Thread-10消费了 初始产品307
# Thread-10消费了 初始产品308
# Thread-13消费了 初始产品309
# Thread-13消费了 初始产品310
# Thread-13消费了 初始产品311
# Thread-14消费了 初始产品312
# Thread-14消费了 初始产品313
# Thread-14消费了 初始产品314
# 生成产品401
# 生成产品402
# 生成产品403
# 生成产品404
# 生成产品405
# 生成产品406
# 生成产品407
# 生成产品408
# 生成产品409
# 生成产品410
# 生成产品411
# 生成产品412
# 生成产品413
# 生成产品414
# 生成产品415
# 生成产品416
# 生成产品417
# 生成产品418
# 生成产品419
# 生成产品420
# 生成产品421
# 生成产品422
# 生成产品423
# 生成产品424
# 生成产品425
# 生成产品426
# 生成产品427
# 生成产品428
# 生成产品429
# 生成产品430
# 生成产品431
# 生成产品432
# 生成产品433
# 生成产品434
# 生成产品435
# 生成产品436
# 生成产品437
# 生成产品438
# 生成产品439
# 生成产品440
# 生成产品441
# 生成产品442
# 生成产品443
# 生成产品444
# 生成产品445
# 生成产品446
# 生成产品447
# 生成产品448
# 生成产品449
# 生成产品450
# 生成产品451
# 生成产品452
# 生成产品453
# 生成产品454
# 生成产品455
# 生成产品456
# 生成产品457
# 生成产品458
# 生成产品459
# 生成产品460
# 生成产品461
# 生成产品462
# 生成产品463
# 生成产品464
# 生成产品465
# 生成产品466
# 生成产品467
# 生成产品468
# 生成产品469
# 生成产品470
# 生成产品471
# 生成产品472
# 生成产品473
# 生成产品474
# 生成产品475
# 生成产品476
# 生成产品477
# 生成产品478
# 生成产品479
# 生成产品480
# 生成产品481
# 生成产品482
# 生成产品483
# 生成产品484
# 生成产品485
# 生成产品486
# 生成产品487
# 生成产品488
# 生成产品489
# 生成产品490
# 生成产品491
# 生成产品492
# 生成产品493
# 生成产品494
# 生成产品495
# 生成产品496
# 生成产品497
# 生成产品498
# 生成产品499
# 生成产品500
# Thread-11消费了 初始产品315
# Thread-11消费了 初始产品316
# Thread-11消费了 初始产品317
# Thread-12消费了 初始产品318
# Thread-12消费了 初始产品319
# Thread-12消费了 初始产品320
# Thread-10消费了 初始产品321
# Thread-10消费了 初始产品322
# Thread-10消费了 初始产品323
# Thread-13消费了 初始产品324
# Thread-13消费了 初始产品325
# Thread-13消费了 初始产品326
# Thread-14消费了 初始产品327
# Thread-14消费了 初始产品328
# Thread-14消费了 初始产品329
# Thread-11消费了 初始产品330
# Thread-11消费了 初始产品331
# Thread-11消费了 初始产品332
# Thread-12消费了 初始产品333
# Thread-12消费了 初始产品334
# Thread-12消费了 初始产品335
# Thread-10消费了 初始产品336
# Thread-10消费了 初始产品337
# Thread-10消费了 初始产品338
# Thread-13消费了 初始产品339
# Thread-13消费了 初始产品340
# Thread-13消费了 初始产品341
# Thread-14消费了 初始产品342
# Thread-14消费了 初始产品343
# Thread-14消费了 初始产品344
# Thread-11消费了 初始产品345
# Thread-11消费了 初始产品346
# Thread-11消费了 初始产品347
# Thread-12消费了 初始产品348
# Thread-12消费了 初始产品349
# Thread-12消费了 初始产品350
# Thread-10消费了 初始产品351
# Thread-10消费了 初始产品352
# Thread-10消费了 初始产品353
# Thread-13消费了 初始产品354
# Thread-13消费了 初始产品355
# Thread-13消费了 初始产品356
# Thread-14消费了 初始产品357
# Thread-14消费了 初始产品358
# Thread-14消费了 初始产品359
# Thread-11消费了 初始产品360
# Thread-11消费了 初始产品361
# Thread-11消费了 初始产品362
# Thread-12消费了 初始产品363
# Thread-12消费了 初始产品364
# Thread-12消费了 初始产品365
# Thread-10消费了 初始产品366
# Thread-10消费了 初始产品367
# Thread-10消费了 初始产品368
# Thread-13消费了 初始产品369
# Thread-13消费了 初始产品370
# Thread-13消费了 初始产品371
# Thread-14消费了 初始产品372
# Thread-14消费了 初始产品373
# Thread-14消费了 初始产品374
# Thread-11消费了 初始产品375
# Thread-11消费了 初始产品376
# Thread-11消费了 初始产品377
# Thread-12消费了 初始产品378
# Thread-12消费了 初始产品379
# Thread-12消费了 初始产品380
# Thread-10消费了 初始产品381
# Thread-10消费了 初始产品382
# Thread-10消费了 初始产品383
# Thread-13消费了 初始产品384
# Thread-13消费了 初始产品385
# Thread-13消费了 初始产品386
# Thread-14消费了 初始产品387
# Thread-14消费了 初始产品388
# Thread-14消费了 初始产品389
# Thread-11消费了 初始产品390
# Thread-11消费了 初始产品391
# Thread-11消费了 初始产品392
# Thread-12消费了 初始产品393
# Thread-12消费了 初始产品394
# Thread-12消费了 初始产品395
# Thread-10消费了 初始产品396
# Thread-10消费了 初始产品397
# Thread-10消费了 初始产品398
# Thread-13消费了 初始产品399
# Thread-13消费了 初始产品400
# Thread-13消费了 初始产品401
# Thread-14消费了 初始产品402
# Thread-14消费了 初始产品403
# Thread-14消费了 初始产品404
# 生成产品501
# 生成产品502
# 生成产品503
# 生成产品504
# 生成产品505
# 生成产品506
# 生成产品507
# 生成产品508
# 生成产品509
# 生成产品510
# 生成产品511
# 生成产品512
# 生成产品513
# 生成产品514
# 生成产品515
# 生成产品516
# 生成产品517
# 生成产品518
# 生成产品519
# 生成产品520
# 生成产品521
# 生成产品522
# 生成产品523
# 生成产品524
# 生成产品525
# 生成产品526
# 生成产品527
# 生成产品528
# 生成产品529
# 生成产品530
# 生成产品531
# 生成产品532
# 生成产品533
# 生成产品534
# 生成产品535
# 生成产品536
# 生成产品537
# 生成产品538
# 生成产品539
# 生成产品540
# 生成产品541
# 生成产品542
# 生成产品543
# 生成产品544
# 生成产品545
# 生成产品546
# 生成产品547
# 生成产品548
# 生成产品549
# 生成产品550
# 生成产品551
# 生成产品552
# 生成产品553
# 生成产品554
# 生成产品555
# 生成产品556
# 生成产品557
# 生成产品558
# 生成产品559
# 生成产品560
# 生成产品561
# 生成产品562
# 生成产品563
# 生成产品564
# 生成产品565
# 生成产品566
# 生成产品567
# 生成产品568
# 生成产品569
# 生成产品570
# 生成产品571
# 生成产品572
# 生成产品573
# 生成产品574
# 生成产品575
# 生成产品576
# 生成产品577
# 生成产品578
# 生成产品579
# 生成产品580
# 生成产品581
# 生成产品582
# 生成产品583
# 生成产品584
# 生成产品585
# 生成产品586
# 生成产品587
# 生成产品588
# 生成产品589
# 生成产品590
# 生成产品591
# 生成产品592
# 生成产品593
# 生成产品594
# 生成产品595
# 生成产品596
# 生成产品597
# 生成产品598
# 生成产品599
# 生成产品600
# Thread-11消费了 初始产品405
# Thread-11消费了 初始产品406
# Thread-11消费了 初始产品407
# Thread-12消费了 初始产品408
# Thread-12消费了 初始产品409
# Thread-12消费了 初始产品410
# Thread-10消费了 初始产品411
# Thread-10消费了 初始产品412
# Thread-10消费了 初始产品413
# Thread-13消费了 初始产品414
# Thread-13消费了 初始产品415
# Thread-13消费了 初始产品416
# Thread-14消费了 初始产品417
# Thread-14消费了 初始产品418
# Thread-14消费了 初始产品419
# Thread-11消费了 初始产品420
# Thread-11消费了 初始产品421
# Thread-11消费了 初始产品422
# Thread-12消费了 初始产品423
# Thread-12消费了 初始产品424
# Thread-12消费了 初始产品425
# Thread-10消费了 初始产品426
# Thread-10消费了 初始产品427
# Thread-10消费了 初始产品428
# Thread-13消费了 初始产品429
# Thread-13消费了 初始产品430
# Thread-13消费了 初始产品431
# Thread-14消费了 初始产品432
# Thread-14消费了 初始产品433
# Thread-14消费了 初始产品434
# Thread-11消费了 初始产品435
# Thread-11消费了 初始产品436
# Thread-11消费了 初始产品437
# Thread-12消费了 初始产品438
# Thread-12消费了 初始产品439
# Thread-12消费了 初始产品440
# Thread-10消费了 初始产品441
# Thread-10消费了 初始产品442
# Thread-10消费了 初始产品443
# Thread-13消费了 初始产品444
# Thread-13消费了 初始产品445
# Thread-13消费了 初始产品446
# Thread-14消费了 初始产品447
# Thread-14消费了 初始产品448
# Thread-14消费了 初始产品449
# Thread-11消费了 初始产品450
# Thread-11消费了 初始产品451
# Thread-11消费了 初始产品452
# Thread-12消费了 初始产品453
# Thread-12消费了 初始产品454
# Thread-12消费了 初始产品455
# Thread-10消费了 初始产品456
# Thread-10消费了 初始产品457
# Thread-10消费了 初始产品458
# Thread-13消费了 初始产品459
# Thread-13消费了 初始产品460
# Thread-13消费了 初始产品461
# Thread-14消费了 初始产品462
# Thread-14消费了 初始产品463
# Thread-14消费了 初始产品464
# Thread-11消费了 初始产品465
# Thread-11消费了 初始产品466
# Thread-11消费了 初始产品467
# Thread-12消费了 初始产品468
# Thread-12消费了 初始产品469
# Thread-12消费了 初始产品470
# Thread-10消费了 初始产品471
# Thread-10消费了 初始产品472
# Thread-10消费了 初始产品473
# Thread-13消费了 初始产品474
# Thread-13消费了 初始产品475
# Thread-13消费了 初始产品476
# Thread-14消费了 初始产品477
# Thread-14消费了 初始产品478
# Thread-14消费了 初始产品479
# Thread-11消费了 初始产品480
# Thread-11消费了 初始产品481
# Thread-11消费了 初始产品482
# Thread-12消费了 初始产品483
# Thread-12消费了 初始产品484
# Thread-12消费了 初始产品485
# Thread-10消费了 初始产品486
# Thread-10消费了 初始产品487
# Thread-10消费了 初始产品488
# Thread-13消费了 初始产品489
# Thread-13消费了 初始产品490
# Thread-13消费了 初始产品491
# Thread-14消费了 初始产品492
# Thread-14消费了 初始产品493
# Thread-14消费了 初始产品494
# Thread-11消费了 初始产品495
# Thread-11消费了 初始产品496
# Thread-11消费了 初始产品497Thread-12消费了 初始产品498
# Thread-12消费了 初始产品499
# Thread-12消费了 生成产品1
#
# Thread-10消费了 生成产品2
# Thread-10消费了 生成产品3
# Thread-10消费了 生成产品4
# Thread-13消费了 生成产品5
# Thread-13消费了 生成产品6
# Thread-13消费了 生成产品7
# Thread-14消费了 生成产品8
# Thread-14消费了 生成产品9
# Thread-14消费了 生成产品10
# 生成产品401
# 生成产品402
# 生成产品403生成产品601
# 生成产品602
# 生成产品603
# 生成产品604
# 生成产品605
# 生成产品606
# 生成产品607
# 生成产品608
# 生成产品609
# 生成产品610
# 生成产品611
# 生成产品612
# 生成产品613
# 生成产品614
# 生成产品615
# 生成产品616
#
# 生成产品617
# 生成产品618
# 生成产品619
# 生成产品620
# 生成产品621
# 生成产品622
# 生成产品623生成产品404
# 生成产品405
# 生成产品406
# 生成产品407
# 生成产品408
# 生成产品409
# 生成产品410
# 生成产品411
# 生成产品412
# 生成产品413
# 生成产品414
# 生成产品415
# 生成产品416
# 生成产品417
# 生成产品418
# 生成产品419
# 生成产品420
# 生成产品421
# 生成产品422
# 生成产品423
# 生成产品424
# 生成产品425
# 生成产品426
# 生成产品427
# 生成产品428
# 生成产品429
# 生成产品430
# 生成产品431
# 生成产品432
# 生成产品433
# 生成产品434
# 生成产品435
# 生成产品436
# 生成产品437
# 生成产品438
# 生成产品439
# 生成产品440
# 生成产品441
# 生成产品442
# 生成产品443
# 生成产品444
# 生成产品445
# 生成产品446
# 生成产品447
# 生成产品448
# 生成产品449
# 生成产品450
# 生成产品451
# 生成产品452
# 生成产品453
# 生成产品454
# 生成产品455
# 生成产品456
# 生成产品457
# 生成产品458
# 生成产品459
# 生成产品460
# 生成产品461
# 生成产品462
# 生成产品463
# 生成产品464
# 生成产品465
# 生成产品466
# 生成产品467
# 生成产品468
# 生成产品469
# 生成产品470
# 生成产品471
# 生成产品472
# 生成产品473
# 生成产品474
# 生成产品475
# 生成产品476
# 生成产品477
# 生成产品478
# 生成产品479
# 生成产品480
#
# 生成产品481
# 生成产品482
# 生成产品483
# 生成产品484
# 生成产品485
# 生成产品486
# 生成产品487
# 生成产品488
# 生成产品489
# 生成产品490
# 生成产品491
# 生成产品492
# 生成产品493
# 生成产品494
# 生成产品495
# 生成产品496
# 生成产品497
# 生成产品498
# 生成产品499
# 生成产品500
# 生成产品624
# 生成产品625
# 生成产品626
# 生成产品627
# 生成产品628
# 生成产品629
# 生成产品630
# 生成产品631
# 生成产品632
# 生成产品633
# 生成产品634
# 生成产品635
# 生成产品636
# 生成产品637
# 生成产品638
# 生成产品639
# 生成产品640
# 生成产品641
# 生成产品642
# 生成产品643
# 生成产品644
# 生成产品645
# 生成产品646
# 生成产品647
# 生成产品648
# 生成产品649
# 生成产品650
# 生成产品651
# 生成产品652
# 生成产品653
# 生成产品654
# 生成产品655
# 生成产品656
# 生成产品657
# 生成产品658
# 生成产品659
# 生成产品660
# 生成产品661
# 生成产品662
# 生成产品663
# 生成产品664
# 生成产品665
# 生成产品666
# 生成产品667
# 生成产品668
# 生成产品669
# 生成产品670
# 生成产品671
# 生成产品672
# 生成产品673
# 生成产品674
# 生成产品675
# 生成产品676
# 生成产品677
# 生成产品678
# 生成产品679
# 生成产品680
# 生成产品681
# 生成产品682
# 生成产品683
# 生成产品684
# 生成产品685
# 生成产品686
# 生成产品687
# 生成产品688
# 生成产品689
# 生成产品690
# 生成产品691
# 生成产品692
# 生成产品693
# 生成产品694
# 生成产品695
# 生成产品696
# 生成产品697
# 生成产品698
# 生成产品699
# 生成产品700
# Thread-12消费了 生成产品11Thread-11消费了 生成产品12
# Thread-11消费了 生成产品13
# Thread-11消费了 生成产品14
#
# Thread-12消费了 生成产品15
# Thread-12消费了 生成产品16
# Thread-10消费了 生成产品17
# Thread-10消费了 生成产品18
# Thread-10消费了 生成产品19
# Thread-13消费了 生成产品20
# Thread-13消费了 生成产品21
# Thread-13消费了 生成产品22
# Thread-14消费了 生成产品23
# Thread-14消费了 生成产品24
# Thread-14消费了 生成产品25
# Thread-11消费了 生成产品26Thread-12消费了 生成产品27
#
# Thread-11消费了 生成产品28
# Thread-12消费了 生成产品1
# Thread-12消费了 生成产品29
# Thread-11消费了 生成产品30
# Thread-10消费了 生成产品31
# Thread-10消费了 生成产品32
# Thread-10消费了 生成产品33
# Thread-13消费了 生成产品34
# Thread-13消费了 生成产品35
# Thread-13消费了 生成产品36
# Thread-14消费了 生成产品37
# Thread-14消费了 生成产品38
# Thread-14消费了 生成产品39

# %%
import threading
import time

lock_1 = threading.Lock()
lock_2 = threading.Lock()

def func_1():
    print("func_1 starting.........")
    lock_1.acquire(timeout=4)
    print("func_1 申请了 lock_1....")
    time.sleep(2)
    print("func_1 等待 lock_2.......")

    rst = lock_2.acquire(timeout=2)
    if rst:
        print("func_1 已经得到锁 lock_2")
        lock_2.release()
        print("func_1 释放了锁 lock_2")
    else:
        print("func_1 注定没申请到lock_2.....")

    lock_1.release()
    print("func_1 释放了 lock_1")

    print("func_1 done..........")


def func_2():
    print("func_2 starting.........")
    lock_2.acquire()
    print("func_2 申请了 lock_2....")
    time.sleep(4)
    print("func_2 等待 lock_1.......")
    lock_1.acquire()
    print("func_2 申请了 lock_1.......")

    lock_1.release()
    print("func_2 释放了 lock_1")

    lock_2.release()
    print("func_2 释放了 lock_2")

    print("func_2 done..........")

if __name__ == "__main__":

    print("主程序启动..............")
    t1 = threading.Thread(target=func_1, args=())
    t2 = threading.Thread(target=func_2, args=())

    t1.start()
    t2.start()

    t1.join()
    t2.join()

    print("主程序结束..............")
# Out:
# 主程序启动..............
# func_1 starting.........
# func_1 申请了 lock_1....
# func_2 starting.........
# func_2 申请了 lock_2....
# func_1 等待 lock_2.......
# func_1 注定没申请到lock_2.....
# func_1 释放了 lock_1
# func_1 done..........
# func_2 等待 lock_1.......
# func_2 申请了 lock_1.......
# func_2 释放了 lock_1
# func_2 释放了 lock_2
# func_2 done..........
# 主程序结束..............

# %% [markdown]
# ### 线程替代方案
#  - subprocess
#       * 完全跳过线程，使用进程
#       * 是派生进程的主要替代方案
#       * python2.4后映入
#       * multiprocessiong
#       - 使用threadiing借口派生，使用子进程
#       - 允许为多核或者多cpu派生进程，接口跟threading非常相似
#       - python2.6
#
# - concurrent.futures
#     - 新的异步执行模块
#     - 任务级别的操作
#     - python3.2后引入
# ### 多进程
# - 进程间通讯(InterprocessCommunication, IPC )
# - 进程之间无任何共享状态
# - 进程的创建
#     - 直接生成Process实例对象， 案例19
#     - 派生子类， 案例20
#
# - 在os中查看pid，ppid以及他们的关系
#     - 案例21
# - 生产者消费者模型
#     - JoinableQueue
#     - 案例22
#     - 队列中哨兵的使用, 案例23
#     - 哨兵的改进， 案例24

# %%
from multiprocessing import Process
import time
def f(n):
    time.sleep(1)
    print(n*n)
if __name__ =="__main__":
    for i in range(10):
        p = Process(target = f,args = [i,])
        p.start()

# %%
import threading
import time
def fun1():
    print("函数一启动")
    time.sleep(3)
    print("结束1")
def fun2():
    print("函数二启动")
    time.sleep(2)
    print("等待函数一")
    print("结束2")
def main():
    print("主程序启动")
    t1 = threading.Thread(target=fun1,args=())
    t2 = threading.Thread(target=fun2,args=())
    
    t1.start()
    t2.start()
    
    t1.join()
    t2.join()
    
    print("主程序结束")

    
if __name__ == "__main__":
    main()
# Out:
# 主程序启动
# 函数一启动
# 函数二启动
# 等待函数一
# 结束2
# 结束1
# 主程序结束
