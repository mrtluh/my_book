# %%
# %matplotlib inline

# %% [markdown]
# <img src="http://jupyter.org/assets/nav_logo.svg" style="border: 2px solid black; float:left" />

# %% [markdown]
# This is a **table**:
#
# | Name | Value |
# |:----:|:-----:|
# |    A |     1 |
# |    B |     2 |
# |    C |     3 |

# %%
from numpy.random import beta
import matplotlib.pyplot as plt


plt.style.use('bmh')


def plot_beta_hist(ax, a, b):
    ax.hist(beta(a, b, size=10000), histtype="stepfilled",
            bins=25, alpha=0.8, density=True)


fig, ax = plt.subplots()
plot_beta_hist(ax, 10, 10)
plot_beta_hist(ax, 4, 12)
plot_beta_hist(ax, 50, 12)
plot_beta_hist(ax, 6, 55)
ax.set_title("'bmh' style sheet")

plt.show()

# %%
#二次函数图像
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 11)
y = x**2

plt.plot(x, y)
plt.show()

# %%
import random

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)

plt.show()

# %%
import random

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D,axes3d

# 球心和半径
center = [1,2,3]
radius = 10

# 数据
u = np.linspace(0,2*np.pi,100)
v = np.linspace(0,np.pi,100)
x = radius * np.outer(np.cos(u),np.sin(v)) + center[0]
y = radius * np.outer(np.sin(u),np.sin(v)) + center[1]
z = radius * np.outer(np.ones(np.size(u)),np.cos(v)) + center[2]

# 绘制图像
fig = plt.figure()
ax  = fig.add_subplot(121,projection='3d')

# 绘制表面
ax.plot_surface(x,y,z,rstride=4,cstride=4,color='b')

# 框架
ax  = fig.add_subplot(122,projection='3d')
ax.plot_wireframe(x,y,z,rstride=10,cstride=10)

# 出图
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))

plt.plot(x, np.cos(x))

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
# 保存绘制的图片
#fig.savefig('my_figure.png')
fig.savefig("my_figure.jpg")

# %%
# 创建两个子图中的第二个，设置坐标轴
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# ### 用matplotlib绘制简易线性图
#
# -      在Matplotlib里面，figure（plt.Figure类的一个实例）可以被看成是一个能够容纳各种坐标轴、图形、文字和标签的容器。就像你在图中看到的那样，
#
# -  axes （plt.Axes类的一个实例）是一个带有刻度和标签的矩形，最终会包含所有可视化的图形元素。在本书中，我们通常会用变量fig表示一个图形实例，用
#
# - 变量ax表 示一个坐标轴实例或一组坐标轴实例。

# %%
# 用matpoltlib 绘制简易线性图

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x),color = "red",linestyle ='-.')

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
fig = plt.figure()
x = np.linspace(0,2*(math.pi),100)
y = np.sin(x)
plt.plot(x,y)
plt.show()
ax = plt.axes()
fig2 = plt.figure()
ax.plot(x,y,color = "red",linestyle = "--")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
fig = plt.figure()
x = np.linspace(0,5,100)
y = x ** 2 * (5 - x) ** (1/2)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
fig = plt.figure()
x = np.linspace(0,0.9,100)
y = x * (1 - x ** 2) ** (- 1 / 2)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
fig = plt.figure
t = np.linspace(0,10,100)
x = 3 * np.sin(t)
y = 3 * np.cos(t)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
fig =plt.figure()

x1 = np.linspace(-0.99,0.99,100)
x2 = np.linspace(1.01,5,100)
x3 = np.linspace(-5,-1.01,100)
x = np.union1d(np.union1d(x1,x2),x3)
# print(x)
# print(type(x))
# print(len(x))
y = (np.e) ** 2 / (x ** 2 - 1)

#time.sleep(20)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()

t = np.linspace(-1,1,100)
a = np.linspace(0,2 * (np.pi),100)
X = np.cos(a) - t*(np.sin(a))
Y = np.sin(a) + t*(np.cos(a))
Z = 2*t

#plt.plot(x,y,z)
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-604534bd8761> in <module>()
#      14 #plt.plot(x,y,z)
#      15 ax = Axes3D(fig)
# ---> 16 ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)
#      17
#      18 plt.show()
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1634
#    1635         if Z.ndim != 2:
# -> 1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#    1638         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
