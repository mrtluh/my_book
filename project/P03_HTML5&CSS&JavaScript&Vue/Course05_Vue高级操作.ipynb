# %% [markdown]
# # Vue基本语法
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#     <script src="./js/vue.js"></script>
#     <script>
#         window.onload = function () {
#
#             // 关联vue对象
#             var vm = new Vue({
#                 // 选择器: 类,ID,标签,伪类选择器,层级选择器 后代选择器, 组选择器
#                 el:'.box',
#                 // 声明属性
#                 data:{
#                     content:"声明属性",
#                     linkUrl:"http://www.itcast.cn",
#                     linkData:"传智",
#                     counter:0,
#                 },
#                 methods:{
#                     // fnAdd:function (){
#                     //     // this 当前操作的对象
#                     //     this.counter += 1
#                     // }
#                 }
#             })
#         }
#     </script>
# </head>
# <body>
#
#     <div class="box">
#         <!-- 1.操作数据  {{}}-->
#         <p>{{ content }}</p>
#
#         <!-- 2..操作属性  v-bind 简写 :-->
#         <a v-bind:href="linkUrl">{{ linkData }}</a>
#         <!-- 3..操作事件 v-on 简写  @-->
#         <!-- <input  v-on:click="fnAdd" type="button" v-bind:value="counter"> -->
#         <input  v-on:click="counter += 1" type="button" v-bind:value="counter">
#
#     </div>
#
#
# </body>
# </html>
# ```

# %% [markdown]
# # Vue条件渲染
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#     <script src="./js/vue.js"></script>
#     <script>
#         window.onload = function () {
#
#             // 关联vue对象
#             var vm = new Vue({
#                 el:'.box',
#                 data:{
#                     age:100,
#                     isShow:false,
#                 }
#             })
#         }
#     </script>
# </head>
# <body>
#
#     <div class="box">
#
#         <!-- v-show 显示和隐藏  display:block  none -->
#         <h1 v-show="isShow">显示和隐藏</h1>
#
#         <!-- <p v-if="age == 100">1</p>
#         <p v-else-if="age == 80">2</p>
#         <p v-else>3</p> -->
#
#         <!-- 条件渲染 v-if 单条件 在用户眼里是显示和隐藏  但是 实际是 删除和创建 -->
#         <!-- <h3 v-if=" age == 10">单条件</h3>
#         <p v-else>条件不满足</p> -->
#
#     </div>
#
#
# </body>
# </html>
#
# ```

# %% [markdown]
# # Vue列表渲染
#
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#     <script src="./js/vue.js"></script>
#     <script>
#         window.onload = function () {
#
#             // 关联vue对象
#           var vm = new Vue({
#               el:'.box',
#               data:{
#                   dataList:['A','B','C','D'],
#                   data_dict:{
#                       'name':'laowang',
#                       'age':88,
#                       'gender':true
#                   },
#                   data_obj_list:[
#                         {
#                             'name':'laowang',
#                             'age':88,
#                             'gender':true
#                         },
#                         {
#                             'name':'laowang',
#                             'age':188,
#                             'gender':true
#                         },
#                         {
#                             'name':'laowang',
#                             'age':288,
#                             'gender':true
#                         },
#                   ]
#               }
#           })
#         }
#     </script>
# </head>
# <body>
#
#     <div class="box">
#         <!-- 列表渲染:只要大量重复的标签 ul ol dl table  =v-for -->
#         <ul>
#             <li v-for="item in data_obj_list">{{ item.age }}</li>
#
#             <li v-for="(value,key) in data_dict">{{key}}---{{value}}</li>
#
#             <!-- <li v-for="(index,item) in dataList">{{index}}---{{ item }}</li> -->
#             <!-- <li v-for="item in dataList">{{ item }}</li> -->
#         </ul>
#
#     </div>
#
#
# </body>
# </html>
#
# ```

# %% [markdown]
# # Vue数据双向绑定
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#
#     <script src="./js/vue.js"></script>
#     <script>
#         window.onload = function () {
#
#             var vm = new Vue({
#                 el:"#app",
#                 data:{
#                    content:"初始化的数据",
#                    like:[]
#                 },
#
#             })
#         }
#     </script>
#
# </head>
# <body>
#
#     <div id="app">
#
#         <!-- 使用vue 只要是 遇到了 input,textarea,select 就用v-model指令 -->
#         <input type="checkbox" name="lk" value="吃饭" v-model='like'>吃饭
#         <input type="checkbox" name="lk" value="睡觉" v-model='like'>睡觉
#         <input type="checkbox" name="lk" value="打豆豆" v-model='like'>打豆豆
#         <p>{{like}}</p>
#
#
#        <!-- 2.双向绑定  v-model-->
#        <input type="text" v-model="content">
#        <p>{{ content }}</p>
#
#        <!-- 1.单向绑定 -->
#        <!-- <input type="text" v-bind:value="content">
#        <p>{{ content }}</p> -->
#     </div>
#     <div>
#         <a href="">
#             <img src="" alt="">
#             <img src="" alt="">
#             <img src="" alt="">
#         </a>
#     </div>
#
# </body>
# </html>
#
# <!-- vue入门小结
#
# vue操作
# 数据  {{ }}
# 属性 v-bind 简写 :
# 事件 v-on 简写 @
#
# 条件渲染: v-if  v-else-if v-else ;
#        显示和隐藏  v-show
# 列表渲染: ul ol dl>dd table 大量重复的标签  v-for="(item,index) in data"
# 双向绑定: 凡是遇到了 input,textarea,select 都是用 v-model -->
#
# ```

# %% [markdown]
# # to do List 案例
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>todolist</title>
# 	<style type="text/css">
# 		.list_con{
# 			width:600px;
# 			margin:50px auto 0;
# 		}
# 		.inputtxt{
# 			width:550px;
# 			height:30px;
# 			border:1px solid #ccc;
# 			padding:0px;
# 			text-indent:10px;
# 		}
# 		.inputbtn{
# 			width:40px;
# 			height:32px;
# 			padding:0px;
# 			border:1px solid #ccc;
# 		}
# 		.list{
# 			margin:0;
# 			padding:0;
# 			list-style:none;
# 			margin-top:20px;
# 		}
# 		.list li{
# 			height:40px;
# 			line-height:40px;
# 			border-bottom:1px solid #ccc;
# 		}
#
# 		.list li span{
# 			float:left;
# 		}
#
# 		.list li a{
# 			float:right;
# 			text-decoration:none;
# 			margin:0 10px;
# 		}
# 	</style>
# 	<script type="text/javascript" src="js/vue.min.js"></script>
# 	<script type="text/javascript">
# 	window.onload = function () {
# 			var vm = new Vue({
#                 el:".list_con",
#                 data:{
#                     inputtxt:"",
#                     datalist:['学习css','学习html','学习javascrip'],
#                 },
#                 methods:{
#                 fnAdd:function(){
#                         if (this.inputtxt == ''){
#                             alert("请输入数据!!!")
#                         }else{
#                             this.datalist.push(this.inputtxt)
#                         }
#                 },
#                 fnDel:function(index){
#                         this.datalist.splice(index,1)
#                 },
#                 fnUp:function(index){
#                     var current = this.datalist[index];
#                     this.datalist.splice(index,1)
#                     this.datalist.splice(index-1,0,current)
#                 },
#                 fnDown:function(index){
#                     var current = this.datalist[index];
#                     this.datalist.splice(index,1)
#                     this.datalist.splice(index+1,0,current)
#                     }
#                 }
#             })
# 	}
# </script>
# </head>
# <body>
#
# 	<div class="list_con">
# 	<h2>To do list</h2>
# 		<input v-model='inputtxt' type="text" name="" id="txt1" class="inputtxt">
# 		<input v-on:click="fnAdd" type="button" name="" value="增加" id="btn1" class="inputbtn">
#
# 		<ul id="list" class="list">
#
# 			<li v-for='(item,index) in datalist'>
#                 <span>{{ item }}</span>
#                 <a v-on:click="fnUp(index)" href="javascript:;" class="Up">↑</a>
#                 <a v-on:click="fnDown(index)" href="javascript:;" class="Down">↓</a>
#                 <a v-on:click="fnDel(index)" href="javascript:;" class="Del">删除</a>
#             </li>
#
# 		</ul>
#
# 	</div>
# </body>
# </html>
# ```

# %% [markdown]
# # ES6.0语法
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#     <script>
#         window.onload = function () {
#
#             // 6.0 变量关键字 let const
#             // 5.o var  先调用 后定义 不报错--undefined
#             // alert(iOne)
#             // var iOne = 100
#
#             // let 不能先调用 后定义
#             // let iOne = 2100
#
#             // 常量--不能修改
#             const iTwo = 100;
#             // iTwo = 200
#
#
#             // 对象的简写: 变量的名字===属性的名字
#             let name = "对象的简写"
#             let age = 18
#             let fnAlert = function () {
#                 alert('简写')
#             }
#
#             let person = {
#                 name,
#                 age,
#                 fnAlert,
#             }
#
#             alert(person.name)
#             person.fnAlert()
#
#
#         }
#     </script>
# </head>
# <body>
#
#
# </body>
# </html>
# ```

# %% [markdown]
# # ES6.0箭头函数
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#     <script>
#         window.onload = function () {
#             // ES6.0 箭头函数-->作用:当js作用域嵌套的时候 this的指向window;==>以前 操作的对象
#             // 写法 : function (){}
#             // 箭头: ()=>{}
#             //      response => {}
#
#
#         var oBtn = document.getElementById('btn')
#
#         oBtn.onclick = function () {
#
#             console.log('嵌套之前this----',this)
#             // 点击按钮 1秒钟之后 弹出提示框
#
#             setTimeout(() => {
#
#                 // alert('谈提示框')
#                 // 修改按钮的背景色
#
#                 console.log('嵌套之后后this----',this)
#                 this.style.background = "red"
#
#             },1000)
#         }
#
#
#
#         }
#     </script>
# </head>
# <body>
#     <button id="btn">点击按钮</button>
#
# </body>
# </html>
#
# ```

# %% [markdown]
# # Vue 的生命周期
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#
#     <script src="./js/vue.js"></script>
#     <script>
#         window.onload = function () {
#
#             var vm = new Vue({
#                 el:"#app",
#                 data:{
#                     counter:0,
#
#                 },
#                 methods:{
#                     fnAdd(){
#
#                     }
#                 },
#
#                 beforeCreate() {
#                     console.log('对象创建之前')
#                     },
#
#                 created() {
#                     console.log('对象创建之后')
#
#                 },
#                 beforeMount() {
#                     console.log('对象加载之前')
#
#                 },
#                 mounted() {
#                     console.log('对象加载之后')
#
#                     // 自动发送 ajax请求 data
#                     // vue标签对象 {{ content }}
#                     //  this.content = data
#
#                 },
#                 beforeUpdate() {
#                     console.log('数据更新之前')
#
#                 },
#                 updated() {
#                     console.log('数据更新之后')
#                 },
#                 beforeDestroy() {
#                     console.log('销毁')
#                 },
#                 destroyed() {
#                     console.log('销毁')
#                 },
#
#             })
#         }
#     </script>
#
# </head>
# <body>
#
#     <div id="app">
#
#        <button @click="counter += 1">{{ counter }}</button>
#
#     </div>
#
# </body>
# </html>
#
# ```

# %% [markdown]
# # Vue 的 axios
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Document</title>
#     <script src="./js/jquery-1.12.4.min.js"></script>
#     <script src="./js/vue.js"></script>
#     <script src="./js/axios.min.js"></script>
#
#     <script>
#         window.onload = function () {
#
#             // jquery
#             $.ajax({
#             // 1.url 请求地址
#             url:'http://t.weather.sojson.com/api/weather/city/101010100',
#             // 2.type 请求方式，默认是'GET'，常用的还有'POST'
#             type:'GET',
#             // 3.dataType 设置返回的数据格式，常用的是'json'格式
#             dataType:'JSON',
#             // 4.data 设置发送给服务器的数据, 没有参数不需要设置
#             // 5.success 设置请求成功后的回调函数
#             success:function (response) {
#                 console.log(response);
#             },
#             // 6.error 设置请求失败后的回调函数
#             error:function () {
#                 alert("请求失败,请稍后再试!");
#             },
#             // 7.async 设置是否异步，默认值是'true'，表示异步，一般不用写
#             async:true
#         });
#
#             // axios
#             axios().then().catch()
#             axios(url)
#             .then(function(response){
#                 response.data
#
#             })
#             .catch(function(error){
#
#             })
#
#
#
#         }
#     </script>
# </head>
# <body>
#
# </body>
# </html>
#
# ```

# %%
# vue 基本语法
7.todoList 案例

8.ES6.0 语法 
    
9.Vue对象的生命周期 mounted  
    创建--beforeCreate ---created
    加载--beforeMount ---mounted(标签对象--改标签属性 改标签包裹内容,ajax请求)
    数据改变--beforeUpdate--updated
    销毁--beforeDestory----destroyed



10.vue请求数据 ajax
    vue.js
    axios.js 
    axios(url,{}).then().catch()



# django基础阶段 复习

# redis:
    /etc/redis/redis.conf 
    bind
    port 
    database 16 0-15
    daemon  yes

    dbfilename dump.dump

    pidfile
     logfile 
            增          删      改          查          
    string: setmset    del    set         get mget   append setex k s v 
    hash     hset           hdel  hset       hget: hgetall()
    list   lpush,rpush lrem   lset        lrange k 0 -1; linsert before/after; ltrim k 0 2
    set    sadd        srem               smembers
    zset   zadd        zrem                zrange   zsocre


# django
    # 1. django创建项目的过程--app-zong-zi--类视图.as_view
    # 2. 配置 mysql
    # 3. 配置 django模板
    # 4. 配置 redis 1. pip install django-redis 2.session_engine=".cache" cache="default"
    # 5. 配置 jinja2模板 1.jinja2_env.py --jinja2环境

    # M model.py class 字段 --数据迁移
        ORM 操作:
            # 增 save()  create()
            # 删 delete()
            # 改 save() ---update()
            # 查 get() book  <----->all() filter() exclude()--querySet(1.惰性执行 懒加载 2.缓存)
            # 关联查询
            1:n(Waijian)  1.模型春晓写_set.filter() 或者 related_name ="sbc"
            n:1            2.n.外键属性
            # 聚合查询 aggregate() Sum Avg Count Max Min
            # 排序 order_by('-id')

            # count()

    # V view: request: 4种传参--4解析
                      method,user,encoding,path
              response: 1.参数 content content_type ="text/html"status
                2.属性 content status_code
                3.子类 JsonResponse({}) 1.dict=>str 2. content_type ="application/json"
                      JsonResponse([],safe=False) 

                      HttpResponse()
                      render()

                      redirect(reverse('总路由:子路由名字'))

            类视图: 写法: urls. 
                  添加装饰器: my_decoraotr(lei.as_view())
                 @ method_decorator(,name="dispatc")
                  class 

                  Mixin
            中间件==装
                位置--给所有的API 都添加功能

                # 1.判断IP
                # 2.判断是否登录
                # 3.统一处理返回结果

    # T 
        {{ }}
        {% for item in data%}
        {% endfor %}
        {% if age > 10%}
        {% endif %}
# git           git pull
 实际开发  工作区  git add .
          暂存区
          本地仓库 git commit -m 
          远程仓库 git push

        git clone https 
                  ssh: 1.生成秘钥 2.粘贴公钥--github gitee

          解决冲突:
                 git pull
                删除>>>>> ===== HEAD
          暂存区
          本地仓库 git commit -m 
          远程仓库 git push

         分支:
            # 1.zhongBUG
            # 2.新的功能
            # 3.分环境

            git checkout -b xx 
            git push -u origin xx 

            git branch
            git checkout master
            git merge xx 
            git push

         标签: 记录版本 备份代码
              git tag -a  v1.0 -m
              git push origin v1.0


# vue--7个指令
{{  }}
v-on  @
v-bind :

v-for="item in datalist"

v-show 

v-if v-else-if 

input,textarea,select=====v-model 

生命周期:mounted 对象加载完毕: 改属性 改数据 发axios

axios 使用
  axios.(url).then().catch()
