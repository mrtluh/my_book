# %% [markdown]
# - 视图定义到views.py中
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 视图基本使用
# - 概述
#    *   在django中，视图对web请求进行回应
#    *   视图就是一个python函数，在views.py文件中进行定义
# - 定义视图
#    *   引入包 from djando.http import HttpResponse
#    *   def index(request):
#    *   return HttpResponse("life is short,I love python")
# - 配置url
#    *   修改project目录下的urls.py文件  子主题
#    *   在myApp应用目录下创建一个urls.py文件  子主题

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 模板的基本使用
# #### 概述
# - 模板是HTTP页面，可以根据视图中传递过来的数据进行填充
#
# ####  创建模板目录
# - 创建templates目录，在目录下创建对应项目的模板目录(project、templates/myApp)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 配置模板路径
# - 修改settings.py文件下的TEMPLATES
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 定义grades.html和students.html模板
# - 模板语法
#     {{输出值，可以是变量，一个可以是对象，属性}}
#     {%执行代码段}
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 需求输入网址，显示信息
# - 输入http://127.0.0.1:8000/grades/  显示班级信息
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 定义视图
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 配置url
# ![image.png](attachment:image.png)

# %% [markdown]
# ####  输入http://127.0.0.1:8000/students/  显示学生信息
# - 第一步写students.html页面
# - 写视图,要导入学生的类 from .models import Students
# - 写url
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 需求点击班级，显示班级的所有学生
# #### 写students模板
#             <li>
#                 <a href="{{grade.id}}">{{grade.gname}}</a>
#             </li>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 定义视图
#     def gradesStudents(request,num):
#         # 获得对应的班级对象
#         grade = Grades.objects.get(pk = num)
#         # 获得班级下所有学生的对象列表
#         studentsList = grade.students_set.all()
#         return render(request,'myApp/students.html',
#                       {"students":studentsList})
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 配置url路径
#
#    *   url(r'^grades/(\d+)$',views.gradesStudents)
#
# ![image.png](attachment:image.png)
