# %% [markdown]
# # 复习
#
# - 图片管理
#     - crud
#     - 图片上传到fastdfs
# - 订单管理
#     - ReadOnlyModelViewSet
#     - 新增方法：
#         - 1.定义方法
#         - 2.添加action装饰器
# - 系统管理
#     - 认证模块提供的系统管理方式：权限、组、用户
#     - User.objects.create_user(***)===>添加组、权限
#     - 重写序列化器create()===>super().create()===>密码加密
#
# # 反馈
#
# - 上传图片时，报文件不存在错误
#     - 原因：ip改变导致
#     - 解决：停止tracker、storage容器，删除容器，创建容器
# - 上传图片时，报配置错误
#     - 解决：修改dev.py中配置文件的路径
# - 上传图片时，报空间不足
#     - 解决：删除不需要的文件，注意清空回收站
# - 创建sku对象时，需要生成静态文件，代码执行时卡住不动
#     - 解决：开启redis
#
# # 今天知识点
#
# - 使用django做前后端分离
# - pyjwt
# - 项目前端阅读
#
# # 使用django做前后端分离
#
# - 两个类
# - 复数：查询多个，创建
# - 单数：查询一个，修改，删除
#
# # pyjwt
#
# - 前后端分离项目，状态保持使用token
# - 找到包pyjwt
#     - 方案一：jwt.io官网，找星最多的
#     - 方案二：由已知知识推导
# - 官网pypi.org
# - 官网jwt.io
# - 包知识点总结：
#     - pyjwt.encode(payload,私钥)===》token
#     - pyjwt.decode(token,私钥)=====》payload
#     - 说明：解码时可能会抛异常，如果有异常表示身份信息无效
#     - 过期时间exp
# - 实现1：登录时生成token
# - 实现2：接收请求时验证token
#
# # fastdfs交互
#
# ### 上传
#
# - 安装包
# - no module ****===>pip install ...
#
# ###  访问
#
# - storage===>nginx===>8888===>fastdfs
# - /etc/hosts===>127.0.0.1====>image.meiduo.site
#
# # 项目前端阅读
#
# - 读路由规则src/router/index.js
# - 找组件
# - 子组件
#
# ```
# <template>...</template>
#
# <script>....</script>
#
# <style>...</style>
# ```
#
# # 总结
#
# ### 重要知识点
#
# - django进行前后端分离开发
# - 实现状态保持：pyjwt
#
# ### 作业
#
# - 完成今天代码
# - 总结drf框架与后台项目
#
# ### 大纲要求
#
# - 能够理解订单表详情数据获取的业务逻辑
#
# ```
# 1.查询
# 2.订单序列化器中引用订单商品序列化器
# 3.订单商品序列化器中引入商品SKU序列化器
# ```
#
# - 能够理解修改订单状态的业务逻辑
#
# ```
# 在视图集中新增视图
# 1.定义方法
# 2.装饰器action
# 3.参数methods=[请求方式]
# 4.参数detail=True或False
#     True===>在路径中接收主键
#     False===>在路径中不接收主键
# 结果===》前缀/pk/方法名称/
# ```
#
# - 能够理解管理员用户的增删改查业务逻辑
#
# ```
# 使用序列化器默认实现
#     1.数据的创建、修改
#     2.多对多关系数据的维护
# 重写：
#     super(类型,self).****
#     密码加密
# ```
