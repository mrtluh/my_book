# %% [markdown]
# # 01-美多商城立项 自习目标
#
# ## 题目1 [综合训练 2遍(时间充分的前提)]
#
# 进入虚拟环境---pip install -r requirements.txt
# <!--如果安装失败, 你看清楚到底是哪个包失败了, 先删除,, 等其他所有的包安装完毕,  单独安装失败的包-->
#
# ### 题干
# 使用django创建美多商城的项目
# 使用git进行源代码管理
# 配置mysql,redis数据库的存储
# 配置jinja2的模板
# 配置日志
# 配置静态文件
#
# ### 训练目标
#
# 1.django创建完整项目的流程
#
# ### 训练提示
# 1. 创建项目之前是不是要分析整个项目的功能需求?
#
# ### 参考答案
# #### 1..---创建项目
#       *     1.1 gitee 创建远程仓库--.gitignore -- *.idea
#       *     1.2 cd Desktop/  git clone  ssh网址   ----配置个人信息 git config user.name  user.email
#       *     1.3 cd meiduo_project_25/   切换虚拟环境--workon django_meiduo
#       *     1.4 django-admin startproject meiduo_mall
#       *     1.5 pycharm 加载 代码---配虚拟环境
#             *       1. pip install -r requirement.txt
#       *     1.6 配 git 的路径 ---verson contrl  +
#
#
# #### 2.---创建项目目录
#        *      1. libs apps(包) static utils templates
#        *      2. 拖拽 response_code.py  拖utils文件
# #### 3. --- 修改配置文件--方便以后需上线切换环境
#        *      1. 创建 项目同名的文件夹下--- settings包--- dev.py ---prod.py--复制的内容 (以前settings.py)
#        *      2. 删除settings.py
#        *      3. manage.py --- 配置 开关
#        *      4. BASE_DIRE = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('__file__'))))
# #### 4.--配置的是 Jinja2的模板
#        *      1.pip install jinja2
#       *       2.utils---jinja2_env.py ----粘贴代码
#        *      3.settings--dev.py ------粘贴代码
#        *      4. pycharm --setting---Language--
#                       * -1.JavaScript --6.0
#                       * -2.template --jinja2
# #### 5.--配置mysql
#        *     1. 创建带有权限的 数据库 用户名 和 密码
#        *     2. settings--dev.py---粘贴
#        *     3. 同名目录 meiduo_mall/__init__.py -- 实例 install_as_MYSQLdb
#
#        *     用户的官方文档 https://yiyibooks.cn/xx/Django_1.11.6/topics/auth/index.html
# #### 6-配置redis
#        *     1.装包 django-redis
#        *     2.dev.py -- 粘贴代码  session --1号库
# #### 7.使用django-redis 操作数据
#       *     1. from django_redis import get_redis_connnection
#       *     2. clinet = get_redis_connnection('名字session')
#       *     3. 增删改查
#
# ####  7-配置日志文件
#     1. dev ---粘贴代码
#     2. git 不支持提交 空文件夹 (*.log被忽略了 导致logs文件夹是空的 ) --新建一个 .gitkeep
#     3. python manage.py shell 做测试 logger.info('')
#
# #### 9-配置本地的域名
#       1. sudo vi /etc/hosts ;  127.0.0.1 www.meiduo.site
#       2. settings-dev.py ----ALLOWED_HOSTS = ['www.meiduo.site']
# #### 10- 创建了 ausers的应用 是的丰富的
#          1. 注册app  'apps.ausers',
#          2. 总路由
#          3. 子路由
#          4. 类视图 def get(): return render()
#         将static--register.html ---移动到 templates
#
#         ## 题目1 [综合训练 2遍(时间充分的前提)]
#
# ## 题目2 [综合训练 1遍]
#
# ### 题干
# 展示用户注册页面,实现User模型类的自定义和数据迁移
#
# ### 训练目标
#
# 1.用户注册页显示功能
#
# ### 训练提示
#
# 1. 注册页面 是不是模板文件??
# 2. User类 是自己写好 还是 使用django自带的好?
#
#
# ### 参考答案
# 参考课件
#
#
# # 复习 ORM 的增删改查 n 遍
# vue 7个指令 :  v-model; v-for; [[ ]]; v-bind : ; v-on @; v-if v-show
#             axios().then().catch()
#
# web开发流程:
#     1.发送请求
#     2.接收解析(
#             1.解析路由
#             2.解析参数 4种: 请求体form POST; 请求头:META; 路径参数:正则; ? GET 请求体非表单 json body
#             3.校验参数 1.前端正常用户 2.爬虫, postman,fildder ,charls,ajax 等等
#             4.业务逻辑
#
#         )
#     3.返回响应对象
#         HttpResponse()
#         JsonResponse()---->前后端分离
#         render(request,'index.html',context) ---->前后端不分离
#         redirect(reverse(''))
#
#      4种请求的方式 post delete put get
