# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,SGDRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.linear_model import Ridge, ElasticNet, Lasso

# %%
# 获取数据
data = pd.read_csv("./data/train_V2.csv")

# %%
# 数据基本处理
data.shape
# Out:
# (4446966, 29)

# %%
# 处理缺失值
np.any(pd.isnull(data))
# Out:
# True

# %%
data.dropna(inplace=True)

# %%
# 判断缺失值是否处理完
np.any((np.any(pd.isna(data))) or (np.any(pd.isnull(data))))
# Out:
# False

# %%
# 缩小数据范围
data = data[:50000]

# %%
data.shape
# Out:
# (50000, 29)

# %%
data.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace      ...       revives  \
# 0         0.00      0              0      0         60      ...             0
# 1        91.47      0              0      0         57      ...             0
# 2        68.00      0              0      0         47      ...             0
# 3        32.90      0              0      0         75      ...             0
# 4       100.00      0              0      0         45      ...             0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# 1        0.0045          0         11.04          0               0
# 2        0.0000          0          0.00          0               0
# 3        0.0000          0          0.00          0               0
# 4        0.0000          0          0.00          0               0
#
#    walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0        244.80                1       1466        0.4444
# 1       1434.00                5          0        0.6400
# 2        161.80                2          0        0.7755
# 3        202.70                3          0        0.1667
# 4         49.75                2          0        0.1875
#
# [5 rows x 29 columns]

# %%
# 确定特征值和目标值
y = data['winPlacePerc']
x_data = ["assists","boosts",
          "damageDealt","DBNOs",
          "headshotKills","heals",
          "killPlace","killPoints",
          "kills","killStreaks","longestKill",
          "matchDuration","maxPlace","numGroups",
          "rankPoints","teamKills"]
x_dict = {}
for i in range(len(x_data)):
    if i > len(x_data) - 2:
        break
    if i < len(x_data)-1:
        for j in (i+1,len(x_data)-1):
            x_list = []
#             print(len(x_data))
#             print(j)
            x_list.append(x_data[i])
            x_list.append(x_data[j])
            
            x = data[x_list]
            # 数据切割
            x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=22)
            # 特征工程
            # 数据标准化
            transfer = StandardScaler()
            x_train = transfer.fit_transform(x_train)
            x_test = transfer.transform(x_test)

            # 建立模型
            estimator = Ridge(alpha=0.1)
            # estimator.fit(x_train,y_train.astype('int'))
            estimator.fit(x_train,y_train)

            # 5.模型评估
            # 5.1 获取系数等值
            y_predict = estimator.predict(x_test)
            print("预测值为:\n", y_predict)
            print("模型中的系数为:\n", estimator.coef_)
            print("模型中的偏置为:\n", estimator.intercept_)

            # 5.2 评价
            # 平均绝对误差（MAE）
            error = mean_absolute_error(y_test, y_predict)
            print("--{}--".format(i))
            print("平均绝对误差:\n", error)
            print()
            x_dict[tuple(x_list)] = error
# Out:
# 预测值为:
#  [0.34059117 0.55322188 0.34059117 ... 0.72234577 0.34059117 0.50971506]
# 模型中的系数为:
#  [0.03644161 0.18350896]
# 模型中的偏置为:
#  0.4745538
# --0--
# 平均绝对误差:
#  0.1950344357599949
#
# 预测值为:
#  [0.43693344 0.43693344 0.43693344 ... 0.5957226  0.43693344 0.5957226 ]
# 模型中的系数为:
#  [0.09212972 0.00477384]
# 模型中的偏置为:
#  0.4745538
# --0--
# 平均绝对误差:
#  0.2532945450846023
#
# 预测值为:
#  [0.36450775 0.57130974 0.32766872 ... 0.68765306 0.35547176 0.48438205]
# 模型中的系数为:
#  [0.16972031 0.0474155 ]
# 模型中的偏置为:
#  0.4745538
# --1--
# 平均绝对误差:
#  0.19450095739585746
#
# 预测值为:
#  [0.34758852 0.57299458 0.34758852 ... 0.68569762 0.34758852 0.46029155]
# 模型中的系数为:
#  [0.19453461 0.00303892]
# 模型中的偏置为:
#  0.4745538
# --1--
# 平均绝对误差:
#  0.19717203174181586
#
# 预测值为:
#  [0.42997778 0.53383379 0.36916078 ... 0.59697468 0.46660043 0.50549351]
# 模型中的系数为:
#  [ 0.16617427 -0.03968121]
# 模型中的偏置为:
#  0.4745538
# --2--
# 平均绝对误差:
#  0.23576914534207352
#
# 预测值为:
#  [0.47491661 0.50409785 0.36898469 ... 0.55590455 0.44893331 0.53687678]
# 模型中的系数为:
#  [0.13634494 0.00426801]
# 模型中的偏置为:
#  0.4745538
# --2--
# 平均绝对误差:
#  0.23681464523190252
#
# 预测值为:
#  [0.61854414 0.41967786 0.41967786 ... 0.41967786 0.51993721 0.61854414]
# 模型中的系数为:
#  [0.05729699 0.05867708]
# 模型中的偏置为:
#  0.4745538
# --3--
# 平均绝对误差:
#  0.2519751413400082
#
# 预测值为:
#  [0.57257573 0.42627584 0.42627584 ... 0.42627584 0.42627584 0.57257573]
# 模型中的系数为:
#  [0.08500967 0.00022082]
# 模型中的偏置为:
#  0.4745538
# --3--
# 平均绝对误差:
#  0.25664663667368354
#
# 预测值为:
#  [0.49353586 0.47962767 0.38954064 ... 0.47962767 0.49353586 0.49353586]
# 模型中的系数为:
#  [0.06086351 0.1199456 ]
# 模型中的偏置为:
#  0.4745538
# --4--
# 平均绝对误差:
#  0.2296843145492541
#
# 预测值为:
#  [0.58762247 0.44120039 0.44120039 ... 0.44120039 0.58762247 0.58762247]
# 模型中的系数为:
#  [0.08569396 0.00485214]
# 模型中的偏置为:
#  0.4745538
# --4--
# 平均绝对误差:
#  0.255946428226895
#
# 预测值为:
#  [0.65417578 0.62939477 0.16604944 ... 0.78238959 0.45746815 0.71974499]
# 模型中的系数为:
#  [ 0.0543071  -0.19985374]
# 模型中的偏置为:
#  0.4745538
# --5--
# 平均绝对误差:
#  0.16303194573932397
#
# 预测值为:
#  [0.40612488 0.50567472 0.40612488 ... 0.50567472 0.40612488 0.40612488]
# 模型中的系数为:
#  [0.13254478 0.00078075]
# 模型中的偏置为:
#  0.4745538
# --5--
# 平均绝对误差:
#  0.2358738359699134
#
# 预测值为:
#  [0.70537043 0.63281529 0.16301937 ... 0.80211063 0.487705   0.77792558]
# 模型中的系数为:
#  [-0.22114674 -0.00133314]
# 模型中的偏置为:
#  0.4745538
# --6--
# 平均绝对误差:
#  0.16647237420336677
#
# 预测值为:
#  [0.70478297 0.63219965 0.16444046 ... 0.80156074 0.48703301 0.7773663 ]
# 模型中的系数为:
#  [-0.22123262 -0.00281869]
# 模型中的偏置为:
#  0.4745538
# --6--
# 平均绝对误差:
#  0.16648951404937776
#
# 预测值为:
#  [0.5643473  0.48100231 0.39663893 ... 0.64769229 0.48100231 0.64769229]
# 模型中的系数为:
#  [-0.00061203  0.12960219]
# 模型中的偏置为:
#  0.4745538
# --7--
# 平均绝对误差:
#  0.23999165168715195
#
# 预测值为:
#  [0.47121071 0.47121071 0.47627669 ... 0.47121071 0.47121071 0.47121071]
# 模型中的系数为:
#  [0.00304451 0.00600141]
# 模型中的偏置为:
#  0.4745538
# --7--
# 平均绝对误差:
#  0.26834057121668736
#
# 预测值为:
#  [0.6106129  0.49946749 0.38832208 ... 0.67743535 0.49946749 0.7217583 ]
# 模型中的系数为:
#  [0.10390949 0.03174511]
# 模型中的偏置为:
#  0.4745538
# --8--
# 平均绝对误差:
#  0.23914457153411012
#
# 预测值为:
#  [0.56325303 0.47995809 0.39666315 ... 0.64654797 0.47995809 0.64654797]
# 模型中的系数为:
#  [0.12952435 0.00375672]
# 模型中的偏置为:
#  0.4745538
# --8--
# 平均绝对误差:
#  0.2399502201927982
#
# 预测值为:
#  [0.59459321 0.54697384 0.38115749 ... 0.73750508 0.49603945 0.67817559]
# 模型中的系数为:
#  [0.06953432 0.08906387]
# 模型中的偏置为:
#  0.4745538
# --9--
# 平均绝对误差:
#  0.2344322549854146
#
# 预测值为:
#  [0.70921426 0.54764533 0.38607641 ... 0.70921426 0.54764533 0.87078318]
# 模型中的系数为:
#  [0.11571936 0.0023072 ]
# 模型中的偏置为:
#  0.4745538
# --9--
# 平均绝对误差:
#  0.2457335293115554
#
# 预测值为:
#  [0.45151366 0.51812663 0.42612281 ... 0.64044235 0.44480261 0.41917714]
# 模型中的系数为:
#  [ 0.12570571 -0.00864737]
# 模型中的偏置为:
#  0.4745538
# --10--
# 平均绝对误差:
#  0.24108602133992954
#
# 预测值为:
#  [0.44396029 0.51348206 0.41688234 ... 0.64481764 0.44189566 0.4249832 ]
# 模型中的系数为:
#  [0.12517599 0.00585456]
# 模型中的偏置为:
#  0.4745538
# --10--
# 平均绝对误差:
#  0.24103422754617296
#
# 预测值为:
#  [0.46599789 0.47620289 0.4788607  ... 0.50227127 0.5055247  0.46518339]
# 模型中的系数为:
#  [-0.00164224  0.01347773]
# 模型中的偏置为:
#  0.4745538
# --11--
# 平均绝对误差:
#  0.2682145957236949
#
# 预测值为:
#  [0.47465479 0.47420547 0.47490753 ... 0.47286219 0.47400421 0.47279198]
# 模型中的系数为:
#  [-0.00121306  0.00593338]
# 模型中的偏置为:
#  0.4745538
# --11--
# 平均绝对误差:
#  0.268379492019239
#
# 预测值为:
#  [0.47436889 0.48029661 0.49170755 ... 0.50986797 0.49413918 0.46768668]
# 模型中的系数为:
#  [-0.19557409  0.20940738]
# 模型中的偏置为:
#  0.4745538000000001
# --12--
# 平均绝对误差:
#  0.26776032570573804
#
# 预测值为:
#  [0.46361344 0.47459044 0.47632365 ... 0.50289955 0.50463276 0.46534665]
# 模型中的系数为:
#  [0.01368178 0.00648702]
# 模型中的偏置为:
#  0.4745538
# --12--
# 平均绝对误差:
#  0.26812145283347044
#
# 预测值为:
#  [0.46822884 0.47979007 0.47273393 ... 0.50874716 0.50930071 0.46909167]
# 模型中的系数为:
#  [0.01397343 0.004623  ]
# 模型中的偏置为:
#  0.4745538
# --13--
# 平均绝对误差:
#  0.26813839515517135
#
# 预测值为:
#  [0.4636753  0.47497534 0.47748645 ... 0.50510875 0.50573653 0.46493086]
# 模型中的系数为:
#  [0.01453165 0.00652705]
# 模型中的偏置为:
#  0.4745538
# --13--
# 平均绝对误差:
#  0.26807793625343945
#
# 预测值为:
#  [0.4773757  0.47816026 0.46747334 ... 0.47813905 0.47808251 0.47698696]
# 模型中的系数为:
#  [0.00521662 0.00568173]
# 模型中的偏置为:
#  0.4745538
# --14--
# 平均绝对误差:
#  0.26831558189295096
#
# 预测值为:
#  [0.4773757  0.47816026 0.46747334 ... 0.47813905 0.47808251 0.47698696]
# 模型中的系数为:
#  [0.00521662 0.00568173]
# 模型中的偏置为:
#  0.4745538
# --14--
# 平均绝对误差:
#  0.26831558189295096

# %%
print(len(x_dict))
x_dict_sort = dict(sorted(x_dict.items(),key=lambda item:item[1]))
# print(x_dict_sort)
for k,v in x_dict_sort.items():
    print(k,"-----",v)
# Out:
# 27
# ('heals', 'killPlace') ----- 0.16196351448395574
# ('killPlace', 'killPoints') ----- 0.16530046844263951
# ('killPlace', 'rankPoints') ----- 0.16530358280272303
# ('boosts', 'damageDealt') ----- 0.19512285919906966
# ('assists', 'boosts') ----- 0.1958174338418712
# ('boosts', 'rankPoints') ----- 0.19772914618003043
# ('headshotKills', 'heals') ----- 0.23073724223742087
# ('killStreaks', 'longestKill') ----- 0.23378711406923755
# ('damageDealt', 'DBNOs') ----- 0.23511618376394963
# ('damageDealt', 'rankPoints') ----- 0.2359738283571998
# ('heals', 'rankPoints') ----- 0.2371909704133221
# ('kills', 'killStreaks') ----- 0.23816253716153848
# ('kills', 'rankPoints') ----- 0.23901266938521476
# ('killPoints', 'kills') ----- 0.23902734874563544
# ('longestKill', 'matchDuration') ----- 0.24022445116653357
# ('longestKill', 'rankPoints') ----- 0.24040110494172057
# ('killStreaks', 'rankPoints') ----- 0.2448222473379177
# ('DBNOs', 'headshotKills') ----- 0.25085789852343654
# ('assists', 'rankPoints') ----- 0.2530446646193457
# ('headshotKills', 'rankPoints') ----- 0.25520025377589783
# ('DBNOs', 'rankPoints') ----- 0.25529303019107724
# ('killPoints', 'rankPoints') ----- 0.2658607177573913
# ('maxPlace', 'numGroups') ----- 0.2675773979939597
# ('numGroups', 'rankPoints') ----- 0.26776402116269427
# ('maxPlace', 'rankPoints') ----- 0.26779418208925215
# ('matchDuration', 'maxPlace') ----- 0.26780256410722625
# ('matchDuration', 'rankPoints') ----- 0.26802481106534476

# %%
# 确定特征值和目标值
y = data['winPlacePerc']
x = data[["assists","boosts",
          "damageDealt","DBNOs",
          "headshotKills","heals",
          "killPlace","killPoints",
          "kills","killStreaks","longestKill",
          "matchDuration","maxPlace","numGroups",
          "rankPoints"]]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=22)
# 特征工程
# 数据标准化
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)

# 建立模型
estimator = SGDRegressor(max_iter=1000)
# estimator.fit(x_train,y_train.astype('int'))
estimator.fit(x_train,y_train)

# 5.模型评估
# 5.1 获取系数等值
y_predict = estimator.predict(x_test)
print("预测值为:\n", y_predict)
print("模型中的系数为:\n", estimator.coef_)
print("模型中的偏置为:\n", estimator.intercept_)

# 5.2 评价
# 平均绝对误差（MAE）
error = mean_absolute_error(y_test, y_predict)
print("平均绝对误差:\n", error)
# Out:
# 预测值为:
#  [0.38363469 0.65259892 0.14725143 ... 0.74306106 0.3347454  0.29891614]
# 模型中的系数为:
#  [ 0.02259406  0.0853314   0.01094456 -0.00575535 -0.00050466  0.01293691
#  -0.30251378  0.00122647 -0.03744688 -0.15445413  0.0160755  -0.01579416
#  -0.29999905  0.314187    0.00053449]
# 模型中的偏置为:
#  [0.47472513]
# 平均绝对误差:
#  0.11960445582469485
