# %%
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabaz_score

# %%
# 1. 构造数据
x,y = make_blobs(n_samples=1000,n_features=2,centers=[[-1,-1],[0,0],[1,1],[2,2]],cluster_std=[0.2,0.2,0.2,0.4])
# 创建画布
plt.figure(figsize=(20,10),dpi=100)
# 绘制图像
plt.scatter(x[:,0],x[:,1])
# 显示图像
plt.show()

# %%
# 2. 建立模型
estimator = KMeans(n_clusters=2)
# 3. 模型评估
pre = estimator.fit_predict(x)
print("评估指标 ",calinski_harabaz_score(x,pre))
# Out:
# 评估指标  3140.0428791724717

# %%
# 创建画布
plt.figure(figsize=(20,10),dpi=100)
# 绘制图像
plt.scatter(x[:,0],x[:,1],c=pre)
# 显示图像
plt.show()

# %%
# 2. 建立模型
estimator = KMeans(n_clusters=4)
# 3. 模型评估
pre = estimator.fit_predict(x)
print("评估指标 ",calinski_harabaz_score(x,pre))
# 创建画布
plt.figure(figsize=(20,10),dpi=100)
# 绘制图像
plt.scatter(x[:,0],x[:,1],c=pre)
# 显示图像
plt.show()
# Out:
# 评估指标  6507.512160943659

# %%
# 2. 建立模型
estimator = KMeans(n_clusters=3)
# 3. 模型评估
pre = estimator.fit_predict(x)
print("评估指标 ",calinski_harabaz_score(x,pre))
# 创建画布
plt.figure(figsize=(20,10),dpi=100)
# 绘制图像
plt.scatter(x[:,0],x[:,1],c=pre)
# 显示图像
plt.show()
# Out:
# 评估指标  3034.0198820890682
