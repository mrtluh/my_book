# %%
from scipy.stats import pearsonr,spearmanr
import matplotlib.pyplot as plt

# %% [markdown]
# # 皮尔逊相关系数

# %%
x1 = [12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9]
x2 = [21.2, 23.9, 32.9, 34.1, 42.5, 43.2, 49.0, 52.8, 59.4, 63.5]

# %%
pearsonr(x1,x2)
# Out:
# (0.9941983762371883, 4.9220899554573455e-09)

# %%
# 创建画布
plt.figure(figsize=(20,10),dpi=100)
# 绘制图像
plt.scatter(x1,x2)
# 显示图像
plt.show()

# %% [markdown]
# # 斯皮尔曼相关系数

# %%
spearmanr(x1,x2)
# Out:
# SpearmanrResult(correlation=0.9999999999999999, pvalue=6.646897422032013e-64)

# %% [markdown]
# # 相关系数矩阵

# %%
import pandas as pd

# %%
from sklearn.datasets import load_boston

# %%
data = load_boston()

# %%
data_d = pd.DataFrame(data.data,columns=data.feature_names)

# %%
data_d['target'] = data.target

# %%
data_d.head()
# Out:
#       CRIM    ZN  INDUS  CHAS   ...    PTRATIO       B  LSTAT  target
# 0  0.00632  18.0   2.31   0.0   ...       15.3  396.90   4.98    24.0
# 1  0.02731   0.0   7.07   0.0   ...       17.8  396.90   9.14    21.6
# 2  0.02729   0.0   7.07   0.0   ...       17.8  392.83   4.03    34.7
# 3  0.03237   0.0   2.18   0.0   ...       18.7  394.63   2.94    33.4
# 4  0.06905   0.0   2.18   0.0   ...       18.7  396.90   5.33    36.2
#
# [5 rows x 14 columns]

# %%
data_d.corr()
# Out:
#              CRIM        ZN     INDUS    ...            B     LSTAT    target
# CRIM     1.000000 -0.199458  0.404471    ...    -0.377365  0.452220 -0.385832
# ZN      -0.199458  1.000000 -0.533828    ...     0.175520 -0.412995  0.360445
# INDUS    0.404471 -0.533828  1.000000    ...    -0.356977  0.603800 -0.483725
# CHAS    -0.055295 -0.042697  0.062938    ...     0.048788 -0.053929  0.175260
# NOX      0.417521 -0.516604  0.763651    ...    -0.380051  0.590879 -0.427321
# RM      -0.219940  0.311991 -0.391676    ...     0.128069 -0.613808  0.695360
# AGE      0.350784 -0.569537  0.644779    ...    -0.273534  0.602339 -0.376955
# DIS     -0.377904  0.664408 -0.708027    ...     0.291512 -0.496996  0.249929
# RAD      0.622029 -0.311948  0.595129    ...    -0.444413  0.488676 -0.381626
# TAX      0.579564 -0.314563  0.720760    ...    -0.441808  0.543993 -0.468536
# PTRATIO  0.288250 -0.391679  0.383248    ...    -0.177383  0.374044 -0.507787
# B       -0.377365  0.175520 -0.356977    ...     1.000000 -0.366087  0.333461
# LSTAT    0.452220 -0.412995  0.603800    ...    -0.366087  1.000000 -0.737663
# target  -0.385832  0.360445 -0.483725    ...     0.333461 -0.737663  1.000000
#
# [14 rows x 14 columns]
